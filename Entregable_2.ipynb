# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisPalominoR/Entregable-2/blob/main/Entregable_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Entregable 2

# %% [markdown]
# La siguiente base de datos es sobre las Edificaciones hechas en San Miguel durante el año 2021 y 2022. La data contiene tanto valores de texto como numéricos. A pesar de ello, la data presenta una gran cantidad de problemas, por lo que se necesita una limpieza de datos.

# %%
import os

# %%
pip show openpyxl
# Out:
# Name: openpyxl
# Version: 3.1.2
# Summary: A Python library to read/write Excel 2010 xlsx/xlsm files
# Home-page: https://openpyxl.readthedocs.io
# Author: See AUTHORS
# Author-email: charlie.clark@clark-consulting.eu
# License: MIT
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: et-xmlfile
# Required-by:

# %%
import pandas as pd

# %%
folder="data"
fileName="Edificaciones.xlsx"
fileToRead=os.path.join(folder,fileName)

# %%
fileName="Edificaciones.xlsx"
fileToRead=os.path.join(folder,fileName)

dataExcel=pd.read_excel(fileToRead)

# %%
df_ordenado = dataExcel.sort_values(by='CODIGO_\nENTIDAD', ascending=True)

# %%
df_ordenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180 entries, 0 to 179
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CODIGO_
# ENTIDAD           180 non-null    int64
#  1   CODIGO_
# UBIGEO            180 non-null    int64
#  2   CODIGO_
# PAIS              180 non-null    object
#  3   DEPARTAMENTO              180 non-null    object
#  4   PROVINCIA                 180 non-null    object
#  5   DISTRITO                  180 non-null    object
#  6   NOMBRE_UO                 180 non-null    object
#  7   GOBIERNO_LOCAL            180 non-null    object
#  8   RUC_GOBIERNO
# _LOCAL       180 non-null    int64
#  9   NUMERO_
# EXPEDIENTE        180 non-null    object
#  10  FECHA_
# INICIO_
# TRAMITE    86 non-null     object
#  11  FECHA_
# EMISION_TRAMITE    168 non-null    object
#  12  NRO_RESOLUCION_
# LICENCIA  171 non-null    object
#  13  TIPO_DOC_
# ...

# %% [markdown]
# ## 1. Limpieza de los títulos de las columnas

# %%
# check headers
df_ordenado.columns
# Out:
# Index(['CODIGO_\nENTIDAD', 'CODIGO_\nUBIGEO', 'CODIGO_\nPAIS', 'DEPARTAMENTO',
#        'PROVINCIA', 'DISTRITO', 'NOMBRE_UO', 'GOBIERNO_LOCAL',
#        'RUC_GOBIERNO\n_LOCAL', 'NUMERO_\nEXPEDIENTE',
#        'FECHA_\nINICIO_\nTRAMITE', 'FECHA_\nEMISION_TRAMITE',
#        'NRO_RESOLUCION_\nLICENCIA', 'TIPO_DOC_\nSOLICITANTE',
#        'NRO_DOC_\nSOLICITANTE', 'UBICACION_PREDIO', 'ZONIFICACION_\nPREDIO',
#        'TIPO_DE_USO', 'TIPO_ALTURA', 'DETALLE_ALTURA',
#        'MODALIDAD_\nAPROBACION', '\nTIPO_OBRA', 'OBRA_\nNUEVA',
#        'OBRA_\nDEMOLICIÓN ', 'OBRA_\nREMODELACIÓN ', 'OBRA_\nAMPLIACIÓN ',
#        'OBRA_\nREFACCIÓN ', 'OBRA_\nCERCO ', 'AREA_TOTAL_\nCONSTRUIDA ',
#        'VALOR_\nOBRA', 'FECHA_\nCORTE'],
#       dtype='object')

# %%
# the quasi duplicates
nColumns=df_ordenado.columns[df_ordenado.columns.str.contains('_\n')]
nColumns
# Out:
# Index(['CODIGO_\nENTIDAD', 'CODIGO_\nUBIGEO', 'CODIGO_\nPAIS',
#        'NUMERO_\nEXPEDIENTE', 'FECHA_\nINICIO_\nTRAMITE',
#        'FECHA_\nEMISION_TRAMITE', 'NRO_RESOLUCION_\nLICENCIA',
#        'TIPO_DOC_\nSOLICITANTE', 'NRO_DOC_\nSOLICITANTE',
#        'ZONIFICACION_\nPREDIO', 'MODALIDAD_\nAPROBACION', 'OBRA_\nNUEVA',
#        'OBRA_\nDEMOLICIÓN ', 'OBRA_\nREMODELACIÓN ', 'OBRA_\nAMPLIACIÓN ',
#        'OBRA_\nREFACCIÓN ', 'OBRA_\nCERCO ', 'AREA_TOTAL_\nCONSTRUIDA ',
#        'VALOR_\nOBRA', 'FECHA_\nCORTE'],
#       dtype='object')

# %%
# the not quasi duplicates
df_ordenado.columns[~df_ordenado.columns.str.contains('_\n')]
# Out:
# Index(['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'NOMBRE_UO', 'GOBIERNO_LOCAL',
#        'RUC_GOBIERNO\n_LOCAL', 'UBICACION_PREDIO', 'TIPO_DE_USO',
#        'TIPO_ALTURA', 'DETALLE_ALTURA', '\nTIPO_OBRA'],
#       dtype='object')

# %%
# save the last one but the first ones:
notnColumns=df_ordenado.columns[~df_ordenado.columns.str.contains('\n')][3:]
notnColumns
# Out:
# Index(['NOMBRE_UO', 'GOBIERNO_LOCAL', 'UBICACION_PREDIO', 'TIPO_DE_USO',
#        'TIPO_ALTURA', 'DETALLE_ALTURA'],
#       dtype='object')

# %% [markdown]
# NOT N COLUMNS: Columnas que no contienen "N"

# %%
# using list comprehension
notnColumns1=[element.split('_') for element in notnColumns]
notnColumns1
# Out:
# [['NOMBRE', 'UO'],
#  ['GOBIERNO', 'LOCAL'],
#  ['UBICACION', 'PREDIO'],
#  ['TIPO', 'DE', 'USO'],
#  ['TIPO', 'ALTURA'],
#  ['DETALLE', 'ALTURA']]

# %%
notnColumns2 = []

# %%
for element in notnColumns1:
    nElement = ' '.join(element)
    notnColumns2.append(nElement)
notnColumns2
# Out:
# ['NOMBRE UO',
#  'GOBIERNO LOCAL',
#  'UBICACION PREDIO',
#  'TIPO DE USO',
#  'TIPO ALTURA',
#  'DETALLE ALTURA']

# %% [markdown]
# RUC GOBIERNO LOCAL

# %%
RUCnColumns=df_ordenado.columns[df_ordenado.columns.str.contains('RUC')]
RUCnColumns
# Out:
# Index(['RUC_GOBIERNO\n_LOCAL'], dtype='object')

# %%
RUCnColumns1=[element.split('\n_') for element in RUCnColumns]
RUCnColumns1
# Out:
# [['RUC_GOBIERNO', 'LOCAL']]

# %%
RUCnColumns2 = []

# %%
for element in RUCnColumns1:
    RUCElement = ' '.join(element)
    RUCnColumns2.append(RUCElement)
RUCnColumns2
# Out:
# ['RUC_GOBIERNO LOCAL']

# %%
RUCnColumns3=[element.split('_') for element in RUCnColumns2]
RUCnColumns3
# Out:
# [['RUC', 'GOBIERNO LOCAL']]

# %%
RUCnColumns4 = []

# %%
for element in RUCnColumns3:
    RUCElement1 = ' '.join(element)
    RUCnColumns4.append(RUCElement1)
RUCnColumns4
# Out:
# ['RUC GOBIERNO LOCAL']

# %% [markdown]
# TIPO DE OBRA

# %%
OBRAnColumns=df_ordenado.columns[df_ordenado.columns.str.contains('TIPO_OBRA')]
OBRAnColumns
# Out:
# Index(['\nTIPO_OBRA'], dtype='object')

# %%
OBRAnColumns1=[element.strip('\n') for element in OBRAnColumns]
OBRAnColumns1
# Out:
# ['TIPO_OBRA']

# %%
OBRAnColumns2=[element.split('_') for element in OBRAnColumns1]
OBRAnColumns2
# Out:
# [['TIPO', 'OBRA']]

# %%
OBRAnColumns3 = []

# %%
for element in OBRAnColumns2:
    OBRAElement1 = ' '.join(element)
    OBRAnColumns3.append(OBRAElement1)
OBRAnColumns3
# Out:
# ['TIPO OBRA']

# %% [markdown]
# N COLUMNS: Columnas que contienen "N"

# %%
nColumnsa=[element.strip(' ') for element in nColumns]
nColumnsa
# Out:
# ['CODIGO_\nENTIDAD',
#  'CODIGO_\nUBIGEO',
#  'CODIGO_\nPAIS',
#  'NUMERO_\nEXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE',
#  'FECHA_\nEMISION_TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA',
#  'TIPO_DOC_\nSOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE',
#  'ZONIFICACION_\nPREDIO',
#  'MODALIDAD_\nAPROBACION',
#  'OBRA_\nNUEVA',
#  'OBRA_\nDEMOLICIÓN',
#  'OBRA_\nREMODELACIÓN',
#  'OBRA_\nAMPLIACIÓN',
#  'OBRA_\nREFACCIÓN',
#  'OBRA_\nCERCO',
#  'AREA_TOTAL_\nCONSTRUIDA',
#  'VALOR_\nOBRA',
#  'FECHA_\nCORTE']

# %%
nColumns1=[element.split('_\n') for element in nColumnsa]
nColumns1
# Out:
# [['CODIGO', 'ENTIDAD'],
#  ['CODIGO', 'UBIGEO'],
#  ['CODIGO', 'PAIS'],
#  ['NUMERO', 'EXPEDIENTE'],
#  ['FECHA', 'INICIO', 'TRAMITE'],
#  ['FECHA', 'EMISION_TRAMITE'],
#  ['NRO_RESOLUCION', 'LICENCIA'],
#  ['TIPO_DOC', 'SOLICITANTE'],
#  ['NRO_DOC', 'SOLICITANTE'],
#  ['ZONIFICACION', 'PREDIO'],
#  ['MODALIDAD', 'APROBACION'],
#  ['OBRA', 'NUEVA'],
#  ['OBRA', 'DEMOLICIÓN'],
#  ['OBRA', 'REMODELACIÓN'],
#  ['OBRA', 'AMPLIACIÓN'],
#  ['OBRA', 'REFACCIÓN'],
#  ['OBRA', 'CERCO'],
#  ['AREA_TOTAL', 'CONSTRUIDA'],
#  ['VALOR', 'OBRA'],
#  ['FECHA', 'CORTE']]

# %%
nColumns2 = []

# %%
for element in nColumns1:
    nElement2 = ' '.join(element)
    nColumns2.append(nElement2)
nColumns2
# Out:
# ['CODIGO ENTIDAD',
#  'CODIGO UBIGEO',
#  'CODIGO PAIS',
#  'NUMERO EXPEDIENTE',
#  'FECHA INICIO TRAMITE',
#  'FECHA EMISION_TRAMITE',
#  'NRO_RESOLUCION LICENCIA',
#  'TIPO_DOC SOLICITANTE',
#  'NRO_DOC SOLICITANTE',
#  'ZONIFICACION PREDIO',
#  'MODALIDAD APROBACION',
#  'OBRA NUEVA',
#  'OBRA DEMOLICIÓN',
#  'OBRA REMODELACIÓN',
#  'OBRA AMPLIACIÓN',
#  'OBRA REFACCIÓN',
#  'OBRA CERCO',
#  'AREA_TOTAL CONSTRUIDA',
#  'VALOR OBRA',
#  'FECHA CORTE']

# %%
nColumns3=[element.split('_') for element in nColumns2]
nColumns3
# Out:
# [['CODIGO ENTIDAD'],
#  ['CODIGO UBIGEO'],
#  ['CODIGO PAIS'],
#  ['NUMERO EXPEDIENTE'],
#  ['FECHA INICIO TRAMITE'],
#  ['FECHA EMISION', 'TRAMITE'],
#  ['NRO', 'RESOLUCION LICENCIA'],
#  ['TIPO', 'DOC SOLICITANTE'],
#  ['NRO', 'DOC SOLICITANTE'],
#  ['ZONIFICACION PREDIO'],
#  ['MODALIDAD APROBACION'],
#  ['OBRA NUEVA'],
#  ['OBRA DEMOLICIÓN'],
#  ['OBRA REMODELACIÓN'],
#  ['OBRA AMPLIACIÓN'],
#  ['OBRA REFACCIÓN'],
#  ['OBRA CERCO'],
#  ['AREA', 'TOTAL CONSTRUIDA'],
#  ['VALOR OBRA'],
#  ['FECHA CORTE']]

# %%
nColumns4 = []

# %%
for element in nColumns3:
    elementn = ' '.join(element)
    nColumns4.append(elementn)
nColumns4
# Out:
# ['CODIGO ENTIDAD',
#  'CODIGO UBIGEO',
#  'CODIGO PAIS',
#  'NUMERO EXPEDIENTE',
#  'FECHA INICIO TRAMITE',
#  'FECHA EMISION TRAMITE',
#  'NRO RESOLUCION LICENCIA',
#  'TIPO DOC SOLICITANTE',
#  'NRO DOC SOLICITANTE',
#  'ZONIFICACION PREDIO',
#  'MODALIDAD APROBACION',
#  'OBRA NUEVA',
#  'OBRA DEMOLICIÓN',
#  'OBRA REMODELACIÓN',
#  'OBRA AMPLIACIÓN',
#  'OBRA REFACCIÓN',
#  'OBRA CERCO',
#  'AREA TOTAL CONSTRUIDA',
#  'VALOR OBRA',
#  'FECHA CORTE']

# %%
change={old:new for old,new in zip(notnColumns,notnColumns2)}
change
# Out:
# {'NOMBRE_UO': 'NOMBRE UO',
#  'GOBIERNO_LOCAL': 'GOBIERNO LOCAL',
#  'UBICACION_PREDIO': 'UBICACION PREDIO',
#  'TIPO_DE_USO': 'TIPO DE USO',
#  'TIPO_ALTURA': 'TIPO ALTURA',
#  'DETALLE_ALTURA': 'DETALLE ALTURA'}

# %%
change2={old:new for old,new in zip(nColumns,nColumns4)}
change2
# Out:
# {'CODIGO_\nENTIDAD': 'CODIGO ENTIDAD',
#  'CODIGO_\nUBIGEO': 'CODIGO UBIGEO',
#  'CODIGO_\nPAIS': 'CODIGO PAIS',
#  'NUMERO_\nEXPEDIENTE': 'NUMERO EXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE': 'FECHA INICIO TRAMITE',
#  'FECHA_\nEMISION_TRAMITE': 'FECHA EMISION TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA': 'NRO RESOLUCION LICENCIA',
#  'TIPO_DOC_\nSOLICITANTE': 'TIPO DOC SOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE': 'NRO DOC SOLICITANTE',
#  'ZONIFICACION_\nPREDIO': 'ZONIFICACION PREDIO',
#  'MODALIDAD_\nAPROBACION': 'MODALIDAD APROBACION',
#  'OBRA_\nNUEVA': 'OBRA NUEVA',
#  'OBRA_\nDEMOLICIÓN ': 'OBRA DEMOLICIÓN',
#  'OBRA_\nREMODELACIÓN ': 'OBRA REMODELACIÓN',
#  'OBRA_\nAMPLIACIÓN ': 'OBRA AMPLIACIÓN',
#  'OBRA_\nREFACCIÓN ': 'OBRA REFACCIÓN',
#  'OBRA_\nCERCO ': 'OBRA CERCO',
#  'AREA_TOTAL_\nCONSTRUIDA ': 'AREA TOTAL CONSTRUIDA',
#  'VALOR_\nOBRA': 'VALOR OBRA',
#  'FECHA_\nCORTE': 'FECHA CORTE'}

# %%
change3={old:new for old,new in zip(OBRAnColumns,OBRAnColumns3)}
change3
# Out:
# {'\nTIPO_OBRA': 'TIPO OBRA'}

# %%
change4={old:new for old,new in zip(RUCnColumns,RUCnColumns4)}
change4
# Out:
# {'RUC_GOBIERNO\n_LOCAL': 'RUC GOBIERNO LOCAL'}

# %%
change.update(change2)
change
# Out:
# {'NOMBRE_UO': 'NOMBRE UO',
#  'GOBIERNO_LOCAL': 'GOBIERNO LOCAL',
#  'UBICACION_PREDIO': 'UBICACION PREDIO',
#  'TIPO_DE_USO': 'TIPO DE USO',
#  'TIPO_ALTURA': 'TIPO ALTURA',
#  'DETALLE_ALTURA': 'DETALLE ALTURA',
#  'CODIGO_\nENTIDAD': 'CODIGO ENTIDAD',
#  'CODIGO_\nUBIGEO': 'CODIGO UBIGEO',
#  'CODIGO_\nPAIS': 'CODIGO PAIS',
#  'NUMERO_\nEXPEDIENTE': 'NUMERO EXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE': 'FECHA INICIO TRAMITE',
#  'FECHA_\nEMISION_TRAMITE': 'FECHA EMISION TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA': 'NRO RESOLUCION LICENCIA',
#  'TIPO_DOC_\nSOLICITANTE': 'TIPO DOC SOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE': 'NRO DOC SOLICITANTE',
#  'ZONIFICACION_\nPREDIO': 'ZONIFICACION PREDIO',
#  'MODALIDAD_\nAPROBACION': 'MODALIDAD APROBACION',
#  'OBRA_\nNUEVA': 'OBRA NUEVA',
#  'OBRA_\nDEMOLICIÓN ': 'OBRA DEMOLICIÓN',
#  'OBRA_\nREMODELACIÓN ': 'OBRA REMODELACIÓN',
#  'OBRA_\nAMPLIACIÓN ': 'OBRA AMPLIACIÓN',
#  'OBRA_\nREFACCIÓN ': 'OBRA REFACCIÓN',
#  'OBRA_\nCERCO ': 'OBRA CERCO',
# ...

# %%
change.update(change3)
change
# Out:
# {'NOMBRE_UO': 'NOMBRE UO',
#  'GOBIERNO_LOCAL': 'GOBIERNO LOCAL',
#  'UBICACION_PREDIO': 'UBICACION PREDIO',
#  'TIPO_DE_USO': 'TIPO DE USO',
#  'TIPO_ALTURA': 'TIPO ALTURA',
#  'DETALLE_ALTURA': 'DETALLE ALTURA',
#  'CODIGO_\nENTIDAD': 'CODIGO ENTIDAD',
#  'CODIGO_\nUBIGEO': 'CODIGO UBIGEO',
#  'CODIGO_\nPAIS': 'CODIGO PAIS',
#  'NUMERO_\nEXPEDIENTE': 'NUMERO EXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE': 'FECHA INICIO TRAMITE',
#  'FECHA_\nEMISION_TRAMITE': 'FECHA EMISION TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA': 'NRO RESOLUCION LICENCIA',
#  'TIPO_DOC_\nSOLICITANTE': 'TIPO DOC SOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE': 'NRO DOC SOLICITANTE',
#  'ZONIFICACION_\nPREDIO': 'ZONIFICACION PREDIO',
#  'MODALIDAD_\nAPROBACION': 'MODALIDAD APROBACION',
#  'OBRA_\nNUEVA': 'OBRA NUEVA',
#  'OBRA_\nDEMOLICIÓN ': 'OBRA DEMOLICIÓN',
#  'OBRA_\nREMODELACIÓN ': 'OBRA REMODELACIÓN',
#  'OBRA_\nAMPLIACIÓN ': 'OBRA AMPLIACIÓN',
#  'OBRA_\nREFACCIÓN ': 'OBRA REFACCIÓN',
#  'OBRA_\nCERCO ': 'OBRA CERCO',
# ...

# %%
change.update(change4)
change
# Out:
# {'NOMBRE_UO': 'NOMBRE UO',
#  'GOBIERNO_LOCAL': 'GOBIERNO LOCAL',
#  'UBICACION_PREDIO': 'UBICACION PREDIO',
#  'TIPO_DE_USO': 'TIPO DE USO',
#  'TIPO_ALTURA': 'TIPO ALTURA',
#  'DETALLE_ALTURA': 'DETALLE ALTURA',
#  'CODIGO_\nENTIDAD': 'CODIGO ENTIDAD',
#  'CODIGO_\nUBIGEO': 'CODIGO UBIGEO',
#  'CODIGO_\nPAIS': 'CODIGO PAIS',
#  'NUMERO_\nEXPEDIENTE': 'NUMERO EXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE': 'FECHA INICIO TRAMITE',
#  'FECHA_\nEMISION_TRAMITE': 'FECHA EMISION TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA': 'NRO RESOLUCION LICENCIA',
#  'TIPO_DOC_\nSOLICITANTE': 'TIPO DOC SOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE': 'NRO DOC SOLICITANTE',
#  'ZONIFICACION_\nPREDIO': 'ZONIFICACION PREDIO',
#  'MODALIDAD_\nAPROBACION': 'MODALIDAD APROBACION',
#  'OBRA_\nNUEVA': 'OBRA NUEVA',
#  'OBRA_\nDEMOLICIÓN ': 'OBRA DEMOLICIÓN',
#  'OBRA_\nREMODELACIÓN ': 'OBRA REMODELACIÓN',
#  'OBRA_\nAMPLIACIÓN ': 'OBRA AMPLIACIÓN',
#  'OBRA_\nREFACCIÓN ': 'OBRA REFACCIÓN',
#  'OBRA_\nCERCO ': 'OBRA CERCO',
# ...

# %%
change
# Out:
# {'NOMBRE_UO': 'NOMBRE UO',
#  'GOBIERNO_LOCAL': 'GOBIERNO LOCAL',
#  'UBICACION_PREDIO': 'UBICACION PREDIO',
#  'TIPO_DE_USO': 'TIPO DE USO',
#  'TIPO_ALTURA': 'TIPO ALTURA',
#  'DETALLE_ALTURA': 'DETALLE ALTURA',
#  'CODIGO_\nENTIDAD': 'CODIGO ENTIDAD',
#  'CODIGO_\nUBIGEO': 'CODIGO UBIGEO',
#  'CODIGO_\nPAIS': 'CODIGO PAIS',
#  'NUMERO_\nEXPEDIENTE': 'NUMERO EXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE': 'FECHA INICIO TRAMITE',
#  'FECHA_\nEMISION_TRAMITE': 'FECHA EMISION TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA': 'NRO RESOLUCION LICENCIA',
#  'TIPO_DOC_\nSOLICITANTE': 'TIPO DOC SOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE': 'NRO DOC SOLICITANTE',
#  'ZONIFICACION_\nPREDIO': 'ZONIFICACION PREDIO',
#  'MODALIDAD_\nAPROBACION': 'MODALIDAD APROBACION',
#  'OBRA_\nNUEVA': 'OBRA NUEVA',
#  'OBRA_\nDEMOLICIÓN ': 'OBRA DEMOLICIÓN',
#  'OBRA_\nREMODELACIÓN ': 'OBRA REMODELACIÓN',
#  'OBRA_\nAMPLIACIÓN ': 'OBRA AMPLIACIÓN',
#  'OBRA_\nREFACCIÓN ': 'OBRA REFACCIÓN',
#  'OBRA_\nCERCO ': 'OBRA CERCO',
# ...

# %%
df_ordenado.rename(columns=change,inplace=True)
df_ordenado.head()
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 115          301285         150136          PE         Lima      Lima
# 116          301285         150136          PE         Lima      Lima
# 117          301285         150136          PE         Lima      Lima
# 118          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# 115  San Miguel  Subgerencia de Obras Privadas     San Miguel
# 116  San Miguel  Subgerencia de Obras Privadas     San Miguel
# 117  San Miguel  Subgerencia de Obras Privadas     San Miguel
# 118  San Miguel  Subgerencia de Obras Privadas     San Miguel
#
#      RUC GOBIERNO LOCAL NUMERO EXPEDIENTE  ...                      TIPO OBRA  \
# 0           20131372184        15636-2022  ...        AMPLIACIÓN/REMODELACIÓN
# ...

# %% [markdown]
# Se actualizaron los valores de los títulos de las columnas de la data.

# %% [markdown]
# ## 2. Limpieza de los datos

# %%
df_ordenado.columns
# Out:
# Index(['CODIGO ENTIDAD', 'CODIGO UBIGEO', 'CODIGO PAIS', 'DEPARTAMENTO',
#        'PROVINCIA', 'DISTRITO', 'NOMBRE UO', 'GOBIERNO LOCAL',
#        'RUC GOBIERNO LOCAL', 'NUMERO EXPEDIENTE', 'FECHA INICIO TRAMITE',
#        'FECHA EMISION TRAMITE', 'NRO RESOLUCION LICENCIA',
#        'TIPO DOC SOLICITANTE', 'NRO DOC SOLICITANTE', 'UBICACION PREDIO',
#        'ZONIFICACION PREDIO', 'TIPO DE USO', 'TIPO ALTURA', 'DETALLE ALTURA',
#        'MODALIDAD APROBACION', 'TIPO OBRA', 'OBRA NUEVA', 'OBRA DEMOLICIÓN',
#        'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN', 'OBRA CERCO',
#        'AREA TOTAL CONSTRUIDA', 'VALOR OBRA', 'FECHA CORTE'],
#       dtype='object')

# %% [markdown]
# Código Entidad

# %%
df_ordenado['CODIGO ENTIDAD'].value_counts(dropna=False).sort_index()
# Out:
# 301285    180
# Name: CODIGO ENTIDAD, dtype: int64

# %% [markdown]
# Código Ubigeo

# %%
df_ordenado['CODIGO UBIGEO'].value_counts(dropna=False).sort_index()
# Out:
# 150136    180
# Name: CODIGO UBIGEO, dtype: int64

# %% [markdown]
# Código País

# %%
df_ordenado['CODIGO PAIS'].value_counts(dropna=False).sort_index()
# Out:
# PE    180
# Name: CODIGO PAIS, dtype: int64

# %% [markdown]
# Departamento

# %%
df_ordenado['DEPARTAMENTO'].value_counts(dropna=False).sort_index()
# Out:
# Lima    180
# Name: DEPARTAMENTO, dtype: int64

# %% [markdown]
# Provincia

# %%
df_ordenado['PROVINCIA'].value_counts(dropna=False).sort_index()
# Out:
# Lima    180
# Name: PROVINCIA, dtype: int64

# %% [markdown]
# Distrito

# %%
df_ordenado['DISTRITO'].value_counts(dropna=False).sort_index()
# Out:
# San Miguel    180
# Name: DISTRITO, dtype: int64

# %% [markdown]
# Nombre Unidad Orgánica

# %%
df_ordenado['NOMBRE UO'].value_counts(dropna=False).sort_index()
# Out:
# Subgerencia de Obras Privadas    180
# Name: NOMBRE UO, dtype: int64

# %% [markdown]
# Gobierno Local

# %%
df_ordenado['GOBIERNO LOCAL'].value_counts(dropna=False).sort_index()
# Out:
# San Miguel    180
# Name: GOBIERNO LOCAL, dtype: int64

# %% [markdown]
# RUC Gobierno Local

# %%
df_ordenado['RUC GOBIERNO LOCAL'].value_counts(dropna=False).sort_index()
# Out:
# 20131372184    180
# Name: RUC GOBIERNO LOCAL, dtype: int64

# %% [markdown]
# Número Expediente

# %%
df_ordenado['NUMERO EXPEDIENTE'].value_counts(dropna=False).sort_index()
# Out:
# 00279-2022    1
# 059-2021      1
# 0637-2022     1
# 10019-2022    1
# 10101-2022    1
#              ..
# 9419-2022     1
# 9457-2022     1
# 9485-2022     1
# 9767-2021     1
# 9935-2022     1
# Name: NUMERO EXPEDIENTE, Length: 179, dtype: int64

# %% [markdown]
# Número de la resolución de licencia

# %%
df_ordenado['NRO RESOLUCION LICENCIA'] = df_ordenado['NRO RESOLUCION LICENCIA'].astype(str)

# %%
df_ordenado['NRO RESOLUCION LICENCIA'].value_counts(dropna=False).sort_index()
# Out:
# 0053-2022    1
# 0069-2022    1
# 0072-2022    1
# 009-2022     1
# 040-2022     1
#             ..
# 97-2022      1
# 991-2022     1
# 994-2022     1
# 995-2022     1
# nan          9
# Name: NRO RESOLUCION LICENCIA, Length: 171, dtype: int64

# %% [markdown]
# Tipo Documento Solicitante

# %%
df_ordenado['TIPO DOC SOLICITANTE'].value_counts(dropna=False).sort_index()
# Out:
# DNI     59
# DNI      4
# RDA      1
# RUC     71
# RUC     16
# NaN     29
# Name: TIPO DOC SOLICITANTE, dtype: int64

# %%
df_ordenado['TIPO DOC SOLICITANTE'] = df_ordenado['TIPO DOC SOLICITANTE'].str.strip()

# %%
df_ordenado['TIPO DOC SOLICITANTE'].value_counts(dropna=False).sort_index()
# Out:
# DNI    63
# RDA     1
# RUC    87
# NaN    29
# Name: TIPO DOC SOLICITANTE, dtype: int64

# %% [markdown]
# Número Documento Solicitante

# %%
df_ordenado['NRO DOC SOLICITANTE'] = pd.to_numeric(df_ordenado['NRO DOC SOLICITANTE'], errors='coerce')
df_ordenado= df_ordenado.dropna(subset=['NRO DOC SOLICITANTE'])
df_ordenado['NRO DOC SOLICITANTE'].astype(int)
# Out:
# 0      20514554014
# 115    20608254421
# 116     2054867913
# 117    20555184086
# 119    20605597204
#           ...
# 61         6862888
# 63     20604661880
# 64     20604661880
# 66     20600986164
# 179    20605359737
# Name: NRO DOC SOLICITANTE, Length: 117, dtype: int64

# %%
df_ordenado['NRO DOC SOLICITANTE'].value_counts(dropna=False).sort_index()
# Out:
# 8.777210e+05    1
# 6.055174e+06    1
# 6.134161e+06    1
# 6.720981e+06    1
# 6.862888e+06    1
#                ..
# 2.060887e+10    1
# 2.060889e+10    2
# 2.060893e+10    1
# 2.060906e+10    1
# 2.050000e+11    1
# Name: NRO DOC SOLICITANTE, Length: 89, dtype: int64

# %% [markdown]
# Ubicación Predio

# %%
df_ordenado['UBICACION PREDIO'].value_counts(dropna=False).sort_index()
# Out:
# AV COSTANERA  2982 - -                                                      1
# AV COSTANERA 2560 -- -                                                      1
# AV LA MARINA  2115 -- -                                                     1
# AV LA MARINA  2201-2235 -P-1-2 40429                                        1
# AV LA MARINA / MONSEÑOR J. DINTILHAC 2201-2235/585 -P-1-2 8 - 9 - 10 -11    1
#                                                                            ..
# JR. MANCO II - -- 5                                                         1
# JR. TALAMBO 161 -- -                                                        1
# PASAJE  VIRGEN DE FATIMA  233 -- -                                          1
# PASAJE LAS ROSAS 179 -- -                                                   1
# PASAJE UNO - -A 14                                                          1
# Name: UBICACION PREDIO, Length: 113, dtype: int64

# %%
df_ordenado['UBICACION PREDIO'] = df_ordenado['UBICACION PREDIO'].str.strip()
# Out:
# <ipython-input-62-0add9f28a840>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ordenado['UBICACION PREDIO'] = df_ordenado['UBICACION PREDIO'].str.strip()

# %%
df_ordenado['UBICACION PREDIO'].value_counts(dropna=False).sort_index()
# Out:
# AV COSTANERA  2982 - -                                                      1
# AV COSTANERA 2560 -- -                                                      1
# AV LA MARINA  2115 -- -                                                     1
# AV LA MARINA  2201-2235 -P-1-2 40429                                        1
# AV LA MARINA / MONSEÑOR J. DINTILHAC 2201-2235/585 -P-1-2 8 - 9 - 10 -11    1
#                                                                            ..
# JR. MANCO II - -- 5                                                         1
# JR. TALAMBO 161 -- -                                                        1
# PASAJE  VIRGEN DE FATIMA  233 -- -                                          1
# PASAJE LAS ROSAS 179 -- -                                                   1
# PASAJE UNO - -A 14                                                          1
# Name: UBICACION PREDIO, Length: 113, dtype: int64

# %% [markdown]
# Zonificación Predio

# %%
df_ordenado['ZONIFICACION PREDIO'].value_counts(dropna=False).sort_index()
# Out:
# CM            4
# CZ            6
# CZ            1
# E1            3
# RDA          20
# RDA Y RDM     1
# RDM          69
# RDM          11
# RDM-CV        1
# NaN           1
# Name: ZONIFICACION PREDIO, dtype: int64

# %%
df_ordenado['ZONIFICACION PREDIO'] = df_ordenado['ZONIFICACION PREDIO'].str.strip()
# Out:
# <ipython-input-65-a31010081ec7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_ordenado['ZONIFICACION PREDIO'] = df_ordenado['ZONIFICACION PREDIO'].str.strip()

# %%
df_ordenado['ZONIFICACION PREDIO'].value_counts(dropna=False).sort_index()
# Out:
# CM            4
# CZ            7
# E1            3
# RDA          20
# RDA Y RDM     1
# RDM          80
# RDM-CV        1
# NaN           1
# Name: ZONIFICACION PREDIO, dtype: int64

# %% [markdown]
# Tipo de Uso

# %%
USO= df_ordenado['TIPO DE USO'].value_counts(dropna=False).sort_index()

# %%
df_ordenado['TIPO DE USO'] = df_ordenado['TIPO DE USO'].str.strip()

# %%
df_ordenado['TIPO DE USO'].value_counts(dropna=False).sort_index()
# Out:
# CERCO                                                 1
# COMERCIO                                             11
# CONJUNTO RESIDENCIAL                                  4
# E1                                                    1
# EDIFICIO MULTIFAMILIAR - MODIFICACION DE PROYECTO     1
# EDUCACION                                             1
# MULTIFAMILIAR                                        45
# MULTIFAMILIAR - COMERCIO                              2
# TERRENO                                               1
# UNIFAMILIAR                                           6
# VIIENDA UNIFAMILIAR                                   1
# VIV.MULTIFAMILIAR                                     1
# VIVIENA UNIFAMILIAR                                   1
# VIVIENDA - COMERCIO                                   2
# VIVIENDA MULTIFAMILIAR                               14
# VIVIENDA UNIFAMILIAR                                 23
# VIVIUENDA UNIFAMILIAR                                 1
# ...

# %%
def UNIFORMIDAD(FAMILIA):
    if pd.isnull(FAMILIA):
        return FAMILIA
    FAMILIA = FAMILIA.upper()
    if 'UNIFAMILIAR' in FAMILIA:
        return 'UNIFAMILIAR'
    elif 'MULTIFAMILIAR' in FAMILIA:
        return 'MULTIFAMILIAR'
    elif "COMERCIO" in FAMILIA:
        return "COMERCIO"
    else:
        return FAMILIA

df_ordenado['TIPO DE USO NORMALIZADO'] = df_ordenado['TIPO DE USO'].apply(UNIFORMIDAD)

USO1= df_ordenado['TIPO DE USO NORMALIZADO'].value_counts(dropna=False).sort_index()
USO1
# Out:
# CERCO                    1
# COMERCIO                13
# CONJUNTO RESIDENCIAL     4
# E1                       1
# EDUCACION                1
# MULTIFAMILIAR           63
# TERRENO                  1
# UNIFAMILIAR             32
# NaN                      1
# Name: TIPO DE USO NORMALIZADO, dtype: int64

# %%
df_ordenado['TIPO DE USO NORMALIZADO']
# Out:
# 0      MULTIFAMILIAR
# 115    MULTIFAMILIAR
# 116    MULTIFAMILIAR
# 117    MULTIFAMILIAR
# 119    MULTIFAMILIAR
#            ...
# 61     MULTIFAMILIAR
# 63       UNIFAMILIAR
# 64       UNIFAMILIAR
# 66       UNIFAMILIAR
# 179    MULTIFAMILIAR
# Name: TIPO DE USO NORMALIZADO, Length: 117, dtype: object

# %%
df_ordenado['TIPO DE USO'] = df_ordenado['TIPO DE USO NORMALIZADO']
df_ordenado
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 115          301285         150136          PE         Lima      Lima
# 116          301285         150136          PE         Lima      Lima
# 117          301285         150136          PE         Lima      Lima
# 119          301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 61           301285         150136          PE         Lima      Lima
# 63           301285         150136          PE         Lima      Lima
# 64           301285         150136          PE         Lima      Lima
# 66           301285         150136          PE         Lima      Lima
# 179          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado = df_ordenado.drop('TIPO DE USO NORMALIZADO', axis=1)

# %% [markdown]
# Tipo de Altura

# %%
df_ordenado['TIPO ALTURA'].value_counts(dropna=False).sort_index()
# Out:
# PISOS     26
# PISOS     91
# Name: TIPO ALTURA, dtype: int64

# %%
df_ordenado['TIPO ALTURA'] = df_ordenado['TIPO ALTURA'].str.strip()

# %%
df_ordenado['TIPO ALTURA'].value_counts(dropna=False).sort_index()
# Out:
# PISOS    117
# Name: TIPO ALTURA, dtype: int64

# %% [markdown]
# Detalle altura

# %%
df_ordenado['DETALLE ALTURA'] = df_ordenado['DETALLE ALTURA'].astype(str)

# %%
df_ordenado['DETALLE ALTURA'].value_counts(dropna=False).sort_index()
# Out:
#  3 PISOS + AZOTEA                  1
# 0                                  1
# 1 PISO                             6
# 1 PISO                             3
# 1 SOTANO+7 PISOS+AZOTEA            1
#                                   ..
# SOTANO+SEMISOTANO+6P+AZ            1
# SOTANO+SEMISOTANO+6PISOS+AZOTEA    1
# SOTANO+SEMISOTANO+8P+AZ            1
# SOTANO+SEMISOTANO+8PISOS           1
# nan                                1
# Name: DETALLE ALTURA, Length: 67, dtype: int64

# %%
df_ordenado['DETALLE ALTURA'] = df_ordenado['DETALLE ALTURA'].str.strip()

# %%
df_ordenado['DETALLE ALTURA'].value_counts(dropna=False).sort_index()
# Out:
# 0                                  1
# 1 PISO                             9
# 1 SOTANO+7 PISOS+AZOTEA            1
# 11P+AZ                             1
# 13:00:00                           1
#                                   ..
# SOTANO+SEMISOTANO+6P+AZ            1
# SOTANO+SEMISOTANO+6PISOS+AZOTEA    1
# SOTANO+SEMISOTANO+8P+AZ            1
# SOTANO+SEMISOTANO+8PISOS           1
# nan                                1
# Name: DETALLE ALTURA, Length: 64, dtype: int64

# %%
def ALTURA(DETALLE):
    if '1P' in DETALLE:
        return '1 PISO'
    elif '2P' in DETALLE:
        return '2 PISOS'
    elif "3P" in DETALLE:
        return "3 PISOS"
    elif "4P" in DETALLE:
        return "4 PISOS"
    elif "5P" in DETALLE:
        return "5 PISOS"
    else:
        return DETALLE

df_ordenado['DETALLE ALTURA'] = df_ordenado['DETALLE ALTURA'].apply(ALTURA)

df_ordenado['DETALLE ALTURA'].value_counts(dropna=False).sort_index()
# Out:
# 0                                              1
# 1 PISO                                        14
# 1 SOTANO+7 PISOS+AZOTEA                        1
# 13:00:00                                       1
# 1SOTANO+17PISOS+AZOTEA                         1
# 2 PISO                                         1
# 2 PISOS                                       18
# 2 PISOS + AZ                                   1
# 2 PISOS + AZOTEA                               4
# 2 SOTANOS + 7 PISOS + AZOTEA                   1
# 2 SOTANOS + SEMISOTANO + 10 PISOS + AZOTEA     1
# 2 SOTANOS+17P+AZ                               1
# 2SOT.+16PISOS+AZO.                             1
# 2SOTANOS+7PISOS+AZOTEA                         1
# 3 PISO                                         1
# 3 PISOS                                       14
# 3 PISOS + AZOTEA                               4
# 3 SOT,+20 PISOS+AZOTEA                         1
# 3 SOT.+18 PISOS+AZO.                           1
# ...

# %%
def ALTURA2(DETALLE2):
    if '1 PISO' in DETALLE2:
        return '1 PISO'
    elif '2 PISO' in DETALLE2:
        return '2 PISOS'
    elif "3 PISO" in DETALLE2:
        return "3 PISOS"
    elif "4 PISO" in DETALLE2:
        return "4 PISOS"
    elif "5 PISO" in DETALLE2:
        return "5 PISOS"
    elif "6P" in DETALLE2:
        return "6 PISOS"
    elif "6 PISO" in DETALLE2:
        return "6 PISOS"
    elif "7 PISO" in DETALLE2:
        return "7 PISOS"
    elif "7P" in DETALLE2:
        return "7 PISOS"
    elif "8 PISO" in DETALLE2:
        return "8 PISOS"
    elif "8P" in DETALLE2:
        return "8 PISOS"
    elif "9 PISO" in DETALLE2:
        return "9 PISOS"
    elif "9P" in DETALLE2:
        return "9 PISOS"
    elif "10 PISO" in DETALLE2:
        return "10 PISOS"
    elif "10P" in DETALLE2:
        return "10 PISOS"
    elif "11 PISO" in DETALLE2:
        return "11 PISOS"
    elif "12 PISO" in DETALLE2:
        return "12 PISOS"
    elif "13 PISO" in DETALLE2:
        return "13 PISOS"
    elif "14 PISO" in DETALLE2:
        return "14 PISOS"
    elif "15 PISO" in DETALLE2:
        return "15 PISOS"
    elif "16 PISO" in DETALLE2:
        return "16 PISOS"
    elif "17 PISO" in DETALLE2:
        return "17 PISOS"
    elif "17P" in DETALLE2:
        return "17 PISOS"
    elif "20 PISOS" in DETALLE2:
        return "20 PISOS"
    elif "20P" in DETALLE2:
        return "20 PISOS"
    elif "13:0" in DETALLE2:
        return ""
    else:
        return DETALLE2

df_ordenado['DETALLE ALTURA NORMALIZADO'] = df_ordenado['DETALLE ALTURA'].apply(ALTURA2)

df_ordenado['DETALLE ALTURA NORMALIZADO'].value_counts(dropna=False).sort_index()
# Out:
#              1
# 0            1
# 1 PISO      14
# 10 PISOS     2
# 2 PISOS     24
# 20 PISOS     5
# 3 PISOS     19
# 4 PISOS      6
# 5 PISOS     13
# 6 PISOS      9
# 7 PISOS     12
# 8 PISOS      6
# 9 PISOS      4
# nan          1
# Name: DETALLE ALTURA NORMALIZADO, dtype: int64

# %%
df_ordenado['DETALLE ALTURA'] = df_ordenado['DETALLE ALTURA NORMALIZADO']
df_ordenado
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 115          301285         150136          PE         Lima      Lima
# 116          301285         150136          PE         Lima      Lima
# 117          301285         150136          PE         Lima      Lima
# 119          301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 61           301285         150136          PE         Lima      Lima
# 63           301285         150136          PE         Lima      Lima
# 64           301285         150136          PE         Lima      Lima
# 66           301285         150136          PE         Lima      Lima
# 179          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado = df_ordenado.drop('DETALLE ALTURA NORMALIZADO', axis=1)

# %% [markdown]
# Modalidad Aprobación

# %%
df_ordenado['MODALIDAD APROBACION'] = df_ordenado['MODALIDAD APROBACION'].astype(str)

# %%
df_ordenado['MODALIDAD APROBACION'].value_counts(dropna=False).sort_index()
# Out:
# " A"                       1
# A                         31
# B                         31
# C                         32
# C                          6
# C  REVISORES URBANOS       6
# C - REVISORES URBANOS      1
# C - REVISORES URBANOS      3
# C REVISORES URBANOS        1
# D                          2
# E1                         2
# nan                        1
# Name: MODALIDAD APROBACION, dtype: int64

# %%
def APROBACION(MODALIDAD):
    if 'C' in MODALIDAD:
        return 'C'
    if "A" in MODALIDAD:
        return "A"
    if "E1" in MODALIDAD:
        return "E"
    else:
        return MODALIDAD

df_ordenado['MODALIDAD APROBACION NORMALIZADO'] = df_ordenado['MODALIDAD APROBACION'].apply(APROBACION)

df_ordenado['MODALIDAD APROBACION NORMALIZADO'].value_counts(dropna=False).sort_index()
# Out:
# A      32
# B      31
# C      49
# D       2
# E       2
# nan     1
# Name: MODALIDAD APROBACION NORMALIZADO, dtype: int64

# %%
df_ordenado['MODALIDAD APROBACION'] = df_ordenado['MODALIDAD APROBACION NORMALIZADO']
df_ordenado
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 115          301285         150136          PE         Lima      Lima
# 116          301285         150136          PE         Lima      Lima
# 117          301285         150136          PE         Lima      Lima
# 119          301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 61           301285         150136          PE         Lima      Lima
# 63           301285         150136          PE         Lima      Lima
# 64           301285         150136          PE         Lima      Lima
# 66           301285         150136          PE         Lima      Lima
# 179          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado = df_ordenado.drop('MODALIDAD APROBACION NORMALIZADO', axis=1)

# %% [markdown]
# Tipo de Obra

# %%
df_ordenado['TIPO OBRA'] = df_ordenado['TIPO OBRA'].astype(str)

# %%
df_ordenado['TIPO OBRA'].value_counts(dropna=False).sort_index()
# Out:
# AMPLIACION                                                         7
# AMPLIACION - DEMOLICION PARCIAL                                    1
# AMPLIACION - REMODELACION                                          5
# AMPLIACION - REMODELACION - DEMOLICION PARCIAL                     1
# AMPLIACIÓN Y REMODELACIÓN                                          2
# AMPLIACIÓN/REMODELACIÓN                                            3
# CERCADO - REMODELACION                                             1
# CERCO PERIMETRICO                                                  3
# DEMOLICION TOTAL                                                  12
# DEMOLICION TOTAL                                                   6
# DMEOLICION TOTAL                                                   1
# LICENCIA AMP,REM,DEM.                                              1
# LICENCIA AMPLIACIÓN - REMODELACIÓN                                 1
# LICENCIA DE AMPLIACIÓN                                             1
# ...

# %%
df_ordenado['TIPO OBRA'] = df_ordenado['TIPO OBRA'].str.strip()

# %%
df_ordenado['TIPO OBRA'].value_counts(dropna=False).sort_index()
# Out:
# AMPLIACION                                                         7
# AMPLIACION - DEMOLICION PARCIAL                                    1
# AMPLIACION - REMODELACION                                          5
# AMPLIACION - REMODELACION - DEMOLICION PARCIAL                     1
# AMPLIACIÓN Y REMODELACIÓN                                          2
# AMPLIACIÓN/REMODELACIÓN                                            3
# CERCADO - REMODELACION                                             1
# CERCO PERIMETRICO                                                  3
# DEMOLICION TOTAL                                                  18
# DMEOLICION TOTAL                                                   1
# LICENCIA AMP,REM,DEM.                                              1
# LICENCIA AMPLIACIÓN - REMODELACIÓN                                 1
# LICENCIA DE AMPLIACIÓN                                             2
# LICENCIA DE AMPLIACIÓN Y REMODELACIÓN                              1
# ...

# %%
def OBRA(DETALLE2):
    if 'MOD. DE PROYECTO' in DETALLE2:
        return 'LICENCIA DE MODIFICACION DE PROYECTO'
    elif 'LICENCIA DE DEMOLICION' in DETALLE2:
        return 'LICENCIA DE DEMOLICION TOTAL'
    elif "LICENCIA DEMOLICION TOTAL" in DETALLE2:
        return "LICENCIA DE DEMOLICION TOTAL"
    elif "LICENCIA OBRA NUEVA - ETAPA 2" in DETALLE2:
        return "LICENCIA OBRA NUEVA ETAPA 2"
    elif "LICENCIA OBRA NUEVA - ETAPA 3" in DETALLE2:
        return "LICENCIA OBRA NUEVA ETAPA 3"
    elif "LICENCIA OBRA NUEVA - ETAPA 4" in DETALLE2:
        return "LICENCIA OBRA NUEVA ETAPA 4"
    elif "OLICION TOTAL" in DETALLE2:
        return "LICENCIA DE DEMOLICION TOTAL"
    elif "AMPLIACIÓN Y REMODELACIÓN" in DETALLE2:
        return "LICENCIA DE AMPLIACION - REMODELACION"
    elif "AMPLIACIÓN/REMODELACIÓN" in DETALLE2:
        return "LICENCIA DE AMPLIACION - REMODELACION"
    elif "AMPLIACION - REMODELACION - DEMOLICION PARCIAL" in DETALLE2:
        return "LICENCIA DE AMPLIACIÓN-REMODELACIÓN Y DEMOLICIÓN PARCIAL"
    elif "LICENCIA AMP,REM,DEM." in DETALLE2:
        return "LICENCIA DE AMPLIACIÓN-REMODELACIÓN Y DEMOLICIÓN PARCIAL"
    elif "CERCADO" in DETALLE2:
        return "LICENCIA DE CERCADO"
    elif "CERCO" in DETALLE2:
        return "LICENCIA DE CERCO"
    elif "AMPLIACION - REMODELACION" in DETALLE2:
        return "LICENCIA DE AMPLIACION - REMODELACION"
    elif "LICENCIA AMPLIACIÓN - REMODELACIÓN " in DETALLE2:
        return "LICENCIA DE AMPLIACION - REMODELACION"
    elif "REMODELACIÓN" in DETALLE2:
        return "LICENCIA DE REMODELACIÓN"
    elif "OBRA NUEVA" in DETALLE2:
        return "LICENCIA DE EDIFICACION OBRA NUEVA"
    elif "NUEVA" in DETALLE2:
        return "LICENCIA DE EDIFICACION OBRA NUEVA"
    elif "AMPLIACION - DEMOLICION PARCIAL" in DETALLE2:
        return "LICENCIA DE AMPLIACION - DEMOLICION PARCIAL"
    elif "AMPLIACION" in DETALLE2:
        return "LICENCIA DE AMPLIACIÓN"
    else:
        return DETALLE2

df_ordenado['TIPO OBRA NORMALIZADO'] = df_ordenado['TIPO OBRA'].apply(OBRA)

df_ordenado['TIPO OBRA NORMALIZADO'].value_counts(dropna=False).sort_index()
# Out:
# LICENCIA DE AMPLIACION - DEMOLICION PARCIAL                  1
# LICENCIA DE AMPLIACION - REMODELACION                       12
# LICENCIA DE AMPLIACIÓN                                       9
# LICENCIA DE AMPLIACIÓN-REMODELACIÓN Y DEMOLICIÓN PARCIAL     2
# LICENCIA DE CERCADO                                          1
# LICENCIA DE CERCO                                            5
# LICENCIA DE DEMOLICION TOTAL                                32
# LICENCIA DE EDIFICACION - AMPLIACIÓN                         1
# LICENCIA DE EDIFICACION OBRA NUEVA                          38
# LICENCIA DE MODIFICACION DE PROYECTO                         6
# LICENCIA DE REMODELACIÓN                                     5
# LICENCIA OBRA NUEVA ETAPA 2                                  1
# LICENCIA OBRA NUEVA ETAPA 3                                  1
# LICENCIA OBRA NUEVA ETAPA 4                                  1
# nan                                                          2
# ...

# %%
df_ordenado['TIPO OBRA'] = df_ordenado['TIPO OBRA NORMALIZADO']
df_ordenado
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 115          301285         150136          PE         Lima      Lima
# 116          301285         150136          PE         Lima      Lima
# 117          301285         150136          PE         Lima      Lima
# 119          301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 61           301285         150136          PE         Lima      Lima
# 63           301285         150136          PE         Lima      Lima
# 64           301285         150136          PE         Lima      Lima
# 66           301285         150136          PE         Lima      Lima
# 179          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado = df_ordenado.drop('TIPO OBRA NORMALIZADO', axis=1)

# %% [markdown]
# Numéricos

# %% [markdown]
# Obra Nueva

# %%
OBRA_NUEVA1 = df_ordenado["OBRA NUEVA"].str.contains('^\d+\.?\d*$', na=False)

# %%
OBRA_NUEVA1 = df_ordenado["OBRA NUEVA"].str.contains('^\d+\.?\d*$', na=False)
OBRA_NUEVA2 = OBRA_NUEVA1.fillna(False)  # O True, dependiendo de la lógica deseada

# %% [markdown]
# Generalización:

# %%
numeric_columns = ['OBRA NUEVA', 'OBRA DEMOLICIÓN',
               'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN',
               'OBRA CERCO','AREA TOTAL CONSTRUIDA', 'VALOR OBRA']

# %%
df_ordenado[['OBRA NUEVA', 'OBRA DEMOLICIÓN',
               'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN',
               'OBRA CERCO','AREA TOTAL CONSTRUIDA', 'VALOR OBRA']]=df_ordenado.iloc[:,[22,23,24,25,26,27,28,29]].replace(',','.',regex=True).replace(" ","",regex=True).replace("ML","",regex=True).replace("M2","",regex=True).replace("´","",regex=True).replace("’","",regex=True).replace("-","",regex=True).replace("--","",regex=True)
df_ordenado[['OBRA NUEVA', 'OBRA DEMOLICIÓN',
               'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN',
               'OBRA CERCO','AREA TOTAL CONSTRUIDA', 'VALOR OBRA']]
# Out:
#     OBRA NUEVA OBRA DEMOLICIÓN OBRA REMODELACIÓN OBRA AMPLIACIÓN  \
# 0                                          97.83          208.46
# 115                        200
# 116    1688.79
# 117    1950.08
# 119   11756.55           65.58            1724.5         2714.76
# ..         ...             ...               ...             ...
# 61      469.88
# 63                      194.28
# 64                      162.24
# 66                         102
# 179     935.32
#
#     OBRA REFACCIÓN OBRA CERCO AREA TOTAL CONSTRUIDA   VALOR OBRA
# 0                                            208.46   225.652.12
# 115                                                      45455.7
# 116                                         1688.79   1561032.09
# 117                                         1950.08   1885715.08
# 119                                                  13322075.74
# ..             ...        ...                   ...          ...
# ...

# %%
def corregir_numero(valor):
    if isinstance(valor, str):
        valor = valor.strip()
        valor = valor.replace(',', '.')
        partes = valor.split('.')
        if len(partes) > 2:
            valor_corregido = ''.join(partes[:-1]) + '.' + partes[-1]
        else:
            valor_corregido = valor
        return valor_corregido
    return valor

df_ordenado['VALOR OBRA'] = df_ordenado['VALOR OBRA'].apply(corregir_numero)

df_ordenado['VALOR OBRA'] = pd.to_numeric(df_ordenado['VALOR OBRA'], errors='coerce')

print(df_ordenado['VALOR OBRA'])
# Out:
# 0        225652.12
# 115       45455.70
# 116     1561032.09
# 117     1885715.08
# 119    13322075.74
#           ...
# 61       359246.75
# 63        88222.55
# 64        88222.55
# 66        14427.90
# 179      752031.05
# Name: VALOR OBRA, Length: 117, dtype: float64

# %%
df_ordenado[['OBRA NUEVA', 'OBRA DEMOLICIÓN',
               'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN',
               'OBRA CERCO','AREA TOTAL CONSTRUIDA', 'VALOR OBRA']]
# Out:
#     OBRA NUEVA OBRA DEMOLICIÓN OBRA REMODELACIÓN OBRA AMPLIACIÓN  \
# 0                                          97.83          208.46
# 115                        200
# 116    1688.79
# 117    1950.08
# 119   11756.55           65.58            1724.5         2714.76
# ..         ...             ...               ...             ...
# 61      469.88
# 63                      194.28
# 64                      162.24
# 66                         102
# 179     935.32
#
#     OBRA REFACCIÓN OBRA CERCO AREA TOTAL CONSTRUIDA   VALOR OBRA
# 0                                            208.46    225652.12
# 115                                                     45455.70
# 116                                         1688.79   1561032.09
# 117                                         1950.08   1885715.08
# 119                                                  13322075.74
# ..             ...        ...                   ...          ...
# ...

# %%
badValues = []
for col in numeric_columns:
    currentBad = df_ordenado.loc[:, col].astype(str).str.contains('^\\d+\\.*\\d*$', na=False)
    badValues.extend(df_ordenado.loc[:, col][~currentBad])
badValues = list(set(badValues))
print(badValues)
# Out:
# ['', nan, nan]

# %%
df_ordenado
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 115          301285         150136          PE         Lima      Lima
# 116          301285         150136          PE         Lima      Lima
# 117          301285         150136          PE         Lima      Lima
# 119          301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 61           301285         150136          PE         Lima      Lima
# 63           301285         150136          PE         Lima      Lima
# 64           301285         150136          PE         Lima      Lima
# 66           301285         150136          PE         Lima      Lima
# 179          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado['NRO DOC SOLICITANTE'] = df_ordenado['NRO DOC SOLICITANTE'] .astype(str)
df_ordenado['NRO DOC SOLICITANTE'].head()
# Out:
# 0      20514554014.0
# 115    20608254421.0
# 116     2054867913.0
# 117    20555184086.0
# 119    20605597204.0
# Name: NRO DOC SOLICITANTE, dtype: object

# %%
df_ordenado[['VALOR OBRA']]
# Out:
#       VALOR OBRA
# 0      225652.12
# 115     45455.70
# 116   1561032.09
# 117   1885715.08
# 119  13322075.74
# ..           ...
# 61     359246.75
# 63      88222.55
# 64      88222.55
# 66      14427.90
# 179    752031.05
#
# [117 rows x 1 columns]

# %% [markdown]
# ## 3. Columnas Categóricas

# %%
df_ordenado['VALOR OBRA CATEGORIA'] = pd.qcut(df_ordenado['VALOR OBRA'], q=3, labels=['Bajo', 'Mediano', 'Alto'])
df_ordenado['VALOR OBRA CATEGORIA']
# Out:
# 0      Mediano
# 115       Bajo
# 116       Alto
# 117       Alto
# 119       Alto
#         ...
# 61     Mediano
# 63        Bajo
# 64        Bajo
# 66        Bajo
# 179    Mediano
# Name: VALOR OBRA CATEGORIA, Length: 117, dtype: category
# Categories (3, object): ['Bajo' < 'Mediano' < 'Alto']

# %%
mapper1 = {'Bajo': 1 ,'Mediano': 3,'Alto':5}
mapper2 = {'E': 1 ,'D': 2,'C':3, "B":4, "A":5}

df_ordenado['VALOR OBRA CATEGORIA'].replace(mapper1,inplace=True)
df_ordenado['MODALIDAD APROBACION'].replace(mapper2,inplace=True)

# %%
df_ordenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 179
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           117 non-null    int64
#  1   CODIGO UBIGEO            117 non-null    int64
#  2   CODIGO PAIS              117 non-null    object
#  3   DEPARTAMENTO             117 non-null    object
#  4   PROVINCIA                117 non-null    object
#  5   DISTRITO                 117 non-null    object
#  6   NOMBRE UO                117 non-null    object
#  7   GOBIERNO LOCAL           117 non-null    object
#  8   RUC GOBIERNO LOCAL       117 non-null    int64
#  9   NUMERO EXPEDIENTE        117 non-null    object
#  10  FECHA INICIO TRAMITE     79 non-null     object
#  11  FECHA EMISION TRAMITE    115 non-null    object
#  12  NRO RESOLUCION LICENCIA  117 non-null    object
#  13  TIPO DOC SOLICITANTE     117 non-null    object
# ...

# %%
newNames=df_ordenado.columns[20]+'_or'
newNames
# Out:
# 'MODALIDAD APROBACION_or'

# %%
df_ordenado[newNames]=df_ordenado.iloc[:,20]
df_ordenado
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 115          301285         150136          PE         Lima      Lima
# 116          301285         150136          PE         Lima      Lima
# 117          301285         150136          PE         Lima      Lima
# 119          301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 61           301285         150136          PE         Lima      Lima
# 63           301285         150136          PE         Lima      Lima
# 64           301285         150136          PE         Lima      Lima
# 66           301285         150136          PE         Lima      Lima
# 179          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
from pandas.api.types import CategoricalDtype
myOrdinal = CategoricalDtype(categories=[1,2,3,4,5], ordered=True)

df_ordenado.loc[:,"MODALIDAD APROBACION_or"].astype(myOrdinal)
# Out:
# 0      3
# 115    5
# 116    3
# 117    3
# 119    3
#       ..
# 61     4
# 63     5
# 64     5
# 66     5
# 179    3
# Name: MODALIDAD APROBACION_or, Length: 117, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %%
df_ordenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 179
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           117 non-null    int64
#  1   CODIGO UBIGEO            117 non-null    int64
#  2   CODIGO PAIS              117 non-null    object
#  3   DEPARTAMENTO             117 non-null    object
#  4   PROVINCIA                117 non-null    object
#  5   DISTRITO                 117 non-null    object
#  6   NOMBRE UO                117 non-null    object
#  7   GOBIERNO LOCAL           117 non-null    object
#  8   RUC GOBIERNO LOCAL       117 non-null    int64
#  9   NUMERO EXPEDIENTE        117 non-null    object
#  10  FECHA INICIO TRAMITE     79 non-null     object
#  11  FECHA EMISION TRAMITE    115 non-null    object
#  12  NRO RESOLUCION LICENCIA  117 non-null    object
#  13  TIPO DOC SOLICITANTE     117 non-null    object
# ...

# %%
df_ordenado["MODALIDAD APROBACION_or"] = df_ordenado["MODALIDAD APROBACION_or"].astype('category')

# %%
df_ordenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 179
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           117 non-null    int64
#  1   CODIGO UBIGEO            117 non-null    int64
#  2   CODIGO PAIS              117 non-null    object
#  3   DEPARTAMENTO             117 non-null    object
#  4   PROVINCIA                117 non-null    object
#  5   DISTRITO                 117 non-null    object
#  6   NOMBRE UO                117 non-null    object
#  7   GOBIERNO LOCAL           117 non-null    object
#  8   RUC GOBIERNO LOCAL       117 non-null    int64
#  9   NUMERO EXPEDIENTE        117 non-null    object
#  10  FECHA INICIO TRAMITE     79 non-null     object
#  11  FECHA EMISION TRAMITE    115 non-null    object
#  12  NRO RESOLUCION LICENCIA  117 non-null    object
#  13  TIPO DOC SOLICITANTE     117 non-null    object
# ...

# %%
ordinalLevels={1:'1_Bajo',2:'2_Mediano-Bajo',3:'3_Mediano',4:'4_Mediano-Alto',5:'5_Alto'}

renameLevels= lambda x:x.cat.rename_categories(ordinalLevels)

df_ordenado.loc[:,"VALOR OBRA CATEGORIA":].apply(renameLevels)
# Out:
#     VALOR OBRA CATEGORIA MODALIDAD APROBACION_or
# 0              3_Mediano               3_Mediano
# 115               1_Bajo                  5_Alto
# 116               5_Alto               3_Mediano
# 117               5_Alto               3_Mediano
# 119               5_Alto               3_Mediano
# ..                   ...                     ...
# 61             3_Mediano          4_Mediano-Alto
# 63                1_Bajo                  5_Alto
# 64                1_Bajo                  5_Alto
# 66                1_Bajo                  5_Alto
# 179            3_Mediano               3_Mediano
#
# [117 rows x 2 columns]

# %%
df_ordenado.loc[:,"VALOR OBRA CATEGORIA":]=df_ordenado.loc[:,"VALOR OBRA CATEGORIA":].apply(renameLevels)
df_ordenado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 179
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           117 non-null    int64
#  1   CODIGO UBIGEO            117 non-null    int64
#  2   CODIGO PAIS              117 non-null    object
#  3   DEPARTAMENTO             117 non-null    object
#  4   PROVINCIA                117 non-null    object
#  5   DISTRITO                 117 non-null    object
#  6   NOMBRE UO                117 non-null    object
#  7   GOBIERNO LOCAL           117 non-null    object
#  8   RUC GOBIERNO LOCAL       117 non-null    int64
#  9   NUMERO EXPEDIENTE        117 non-null    object
#  10  FECHA INICIO TRAMITE     79 non-null     object
#  11  FECHA EMISION TRAMITE    115 non-null    object
#  12  NRO RESOLUCION LICENCIA  117 non-null    object
#  13  TIPO DOC SOLICITANTE     117 non-null    object
# ...

# %%
df_ordenado['OBRA NUEVA'] = pd.to_numeric(df_ordenado['OBRA NUEVA'], errors='coerce')

# %%
df_ordenado['OBRA DEMOLICIÓN'] = pd.to_numeric(df_ordenado['OBRA DEMOLICIÓN'], errors='coerce')

# %%
df_ordenado['OBRA AMPLIACIÓN'] = pd.to_numeric(df_ordenado['OBRA AMPLIACIÓN'], errors='coerce')

# %%
df_ordenado['OBRA REFACCIÓN'] = pd.to_numeric(df_ordenado['OBRA REFACCIÓN'], errors='coerce')

# %%
df_ordenado['OBRA CERCO'] = pd.to_numeric(df_ordenado['OBRA CERCO'], errors='coerce')

# %%
df_ordenado['AREA TOTAL CONSTRUIDA'] = pd.to_numeric(df_ordenado['AREA TOTAL CONSTRUIDA'], errors='coerce')

# %% [markdown]
# ## 4. Fechas

# %%
def FECHAS(CAMBIO):
    CAMBIO_str = str(CAMBIO)
    if '10/02/0202' in CAMBIO_str:
        return "20221002"
    elif '226/04/2022' in CAMBIO_str:
        return '20220426'
    elif "17//08/2021" in CAMBIO_str:
        return "20210817"
    else:
        return CAMBIO_str

df_ordenado['FECHA INICIO TRAMITE'] = df_ordenado['FECHA INICIO TRAMITE'].apply(FECHAS)
df_ordenado['FECHA INICIO TRAMITE'].value_counts(dropna=False).sort_index().head()
# Out:
# 20200127    1
# 20210214    1
# 20210514    1
# 20210531    1
# 20210810    1
# Name: FECHA INICIO TRAMITE, dtype: int64

# %%
df_ordenado['FECHA INICIO TRAMITE'] = pd.to_datetime(df_ordenado['FECHA INICIO TRAMITE'], format='%Y%m%d')
df_ordenado['FECHA INICIO TRAMITE'].head()
# Out:
# 0     2021-12-15
# 115   2022-05-13
# 116   2022-03-10
# 117   2022-03-14
# 119   2022-09-09
# Name: FECHA INICIO TRAMITE, dtype: datetime64[ns]

# %%
def FECHAS2(CAMBIO2):
    CAMBIO_str2 = str(CAMBIO2)
    if '16//06/2022' in CAMBIO_str2:
        return "20220616"
    else:
        return CAMBIO_str2

df_ordenado['FECHA EMISION TRAMITE'] = df_ordenado['FECHA EMISION TRAMITE'].apply(FECHAS2)
df_ordenado['FECHA EMISION TRAMITE'].value_counts(dropna=False).sort_index().head()
# Out:
# 20210301    1
# 20211213    1
# 20211221    1
# 20220113    1
# 20220121    2
# Name: FECHA EMISION TRAMITE, dtype: int64

# %%
df_ordenado['FECHA EMISION TRAMITE'] = pd.to_datetime(df_ordenado['FECHA EMISION TRAMITE'], format='%Y%m%d')
df_ordenado['FECHA EMISION TRAMITE'].head()
# Out:
# 0     2022-12-11
# 115   2022-08-29
# 116   2022-08-24
# 117   2022-08-25
# 119   2022-09-15
# Name: FECHA EMISION TRAMITE, dtype: datetime64[ns]

# %%
df_ordenado['FECHA CORTE'] = pd.to_datetime(df_ordenado['FECHA CORTE'], format='%Y%m%d')
df_ordenado['FECHA CORTE'].head()
# Out:
# 0     2022-12-31
# 115   2022-12-31
# 116   2022-12-31
# 117   2022-12-31
# 119   2022-12-31
# Name: FECHA CORTE, dtype: datetime64[ns]

# %%
df_ordenado['AÑO'] = 2022
df_ordenado
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 115          301285         150136          PE         Lima      Lima
# 116          301285         150136          PE         Lima      Lima
# 117          301285         150136          PE         Lima      Lima
# 119          301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 61           301285         150136          PE         Lima      Lima
# 63           301285         150136          PE         Lima      Lima
# 64           301285         150136          PE         Lima      Lima
# 66           301285         150136          PE         Lima      Lima
# 179          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %% [markdown]
# ## 5. Operaciones

# %% [markdown]
# Agregación

# %%
df_ordenado.columns
# Out:
# Index(['CODIGO ENTIDAD', 'CODIGO UBIGEO', 'CODIGO PAIS', 'DEPARTAMENTO',
#        'PROVINCIA', 'DISTRITO', 'NOMBRE UO', 'GOBIERNO LOCAL',
#        'RUC GOBIERNO LOCAL', 'NUMERO EXPEDIENTE', 'FECHA INICIO TRAMITE',
#        'FECHA EMISION TRAMITE', 'NRO RESOLUCION LICENCIA',
#        'TIPO DOC SOLICITANTE', 'NRO DOC SOLICITANTE', 'UBICACION PREDIO',
#        'ZONIFICACION PREDIO', 'TIPO DE USO', 'TIPO ALTURA', 'DETALLE ALTURA',
#        'MODALIDAD APROBACION', 'TIPO OBRA', 'OBRA NUEVA', 'OBRA DEMOLICIÓN',
#        'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN', 'OBRA CERCO',
#        'AREA TOTAL CONSTRUIDA', 'VALOR OBRA', 'FECHA CORTE',
#        'VALOR OBRA CATEGORIA', 'MODALIDAD APROBACION_or', 'AÑO'],
#       dtype='object')

# %%
toSelect=['AREA TOTAL CONSTRUIDA', 'VALOR OBRA','TIPO DE USO', 'TIPO DOC SOLICITANTE']
df_2=df_ordenado[toSelect]
df_2
# Out:
#      AREA TOTAL CONSTRUIDA   VALOR OBRA    TIPO DE USO TIPO DOC SOLICITANTE
# 0                   208.46    225652.12  MULTIFAMILIAR                  RUC
# 115                    NaN     45455.70  MULTIFAMILIAR                  RUC
# 116                1688.79   1561032.09  MULTIFAMILIAR                  RUC
# 117                1950.08   1885715.08  MULTIFAMILIAR                  RUC
# 119                    NaN  13322075.74  MULTIFAMILIAR                  RUC
# ..                     ...          ...            ...                  ...
# 61                  469.88    359246.75  MULTIFAMILIAR                  DNI
# 63                     NaN     88222.55    UNIFAMILIAR                  RUC
# 64                     NaN     88222.55    UNIFAMILIAR                  RUC
# 66                     NaN     14427.90    UNIFAMILIAR                  RUC
# 179                 935.32    752031.05  MULTIFAMILIAR                  RUC
#
# [117 rows x 4 columns]

# %% [markdown]
# Área Total Construida por Tipo de Uso

# %%
AREA_POR_TIPO=df_2.groupby('TIPO DE USO').agg({'AREA TOTAL CONSTRUIDA': 'sum'})
AREA_POR_TIPO
# Out:
#                       AREA TOTAL CONSTRUIDA
# TIPO DE USO
# CERCO                                  0.00
# COMERCIO                            9288.02
# CONJUNTO RESIDENCIAL               34455.25
# E1                                     0.00
# EDUCACION                             31.89
# MULTIFAMILIAR                     385731.87
# TERRENO                               10.00
# UNIFAMILIAR                          995.72

# %% [markdown]
# Área Total Construida por Tipo de Uso y Tipo de Documento Solicitante

# %%
AREA_POR_TIPO_O_D=df_2.groupby(['TIPO DE USO','TIPO DOC SOLICITANTE']).agg({'AREA TOTAL CONSTRUIDA': 'sum'})
AREA_POR_TIPO_O_D
# Out:
#                                            AREA TOTAL CONSTRUIDA
# TIPO DE USO          TIPO DOC SOLICITANTE
# CERCO                RUC                                    0.00
# COMERCIO             DNI                                  130.00
#                      RDA                                   93.37
#                      RUC                                 9064.65
# CONJUNTO RESIDENCIAL RUC                                34455.25
# E1                   RUC                                    0.00
# EDUCACION            RUC                                   31.89
# MULTIFAMILIAR        DNI                               324688.94
#                      RUC                                61042.93
# TERRENO              RUC                                   10.00
# UNIFAMILIAR          DNI                                  823.25
#                      RUC                                  172.47

# %% [markdown]
# Sumas y Medias del Valor de la Obra por Tipo de Uso y Tipo de Documento Solicitante

# %%
AREA_POR_TIPO_FECHA_SUM_MEDIAS=df_2.groupby(['TIPO DE USO','TIPO DOC SOLICITANTE']).agg({'VALOR OBRA': ['sum','mean']})
AREA_POR_TIPO_FECHA_SUM_MEDIAS
# Out:
#                                              VALOR OBRA
#                                                     sum          mean
# TIPO DE USO          TIPO DOC SOLICITANTE
# CERCO                RUC                   3.180175e+04  3.180175e+04
# COMERCIO             DNI                   1.474092e+05  1.474092e+05
#                      RDA                   9.583479e+06  9.583479e+06
#                      RUC                   7.789109e+07  7.081008e+06
# CONJUNTO RESIDENCIAL RUC                   1.240550e+08  3.101375e+07
# E1                   RUC                   1.433861e+06  1.433861e+06
# EDUCACION            RUC                   7.621607e+04  7.621607e+04
# MULTIFAMILIAR        DNI                   5.508966e+06  2.623317e+05
#                      RUC                   2.719951e+08  6.476073e+06
# TERRENO              RUC                   4.091904e+04  4.091904e+04
# UNIFAMILIAR          DNI                   5.830509e+05  8.329299e+04
# ...

# %% [markdown]
# Área Total Construida y Valor de Obra por Tipo de Uso

# %%
AREA_OBRA_TIPO_USO=df_2.groupby('TIPO DE USO').agg({'AREA TOTAL CONSTRUIDA': 'sum', 'VALOR OBRA': 'sum'})
AREA_OBRA_TIPO_USO
# Out:
#                       AREA TOTAL CONSTRUIDA    VALOR OBRA
# TIPO DE USO
# CERCO                                  0.00  3.180175e+04
# COMERCIO                            9288.02  8.762197e+07
# CONJUNTO RESIDENCIAL               34455.25  1.240550e+08
# E1                                     0.00  1.433861e+06
# EDUCACION                             31.89  7.621607e+04
# MULTIFAMILIAR                     385731.87  2.775040e+08
# TERRENO                               10.00  4.091904e+04
# UNIFAMILIAR                          995.72  3.036016e+06

# %% [markdown]
# Sumas y Medias del Área Total Construida y Valor de Obra por Tipo de Uso y Tipo de Documento Solicitante

# %%
AREA_OBRA_TIPO_USO_DOC=df_2.groupby(['TIPO DE USO','TIPO DOC SOLICITANTE']).agg({'AREA TOTAL CONSTRUIDA': ['sum','mean'], 'VALOR OBRA': ['sum','mean']})
AREA_OBRA_TIPO_USO_DOC
# Out:
#                                           AREA TOTAL CONSTRUIDA                \
#                                                             sum          mean
# TIPO DE USO          TIPO DOC SOLICITANTE
# CERCO                RUC                                   0.00           NaN
# COMERCIO             DNI                                 130.00    130.000000
#                      RDA                                  93.37     93.370000
#                      RUC                                9064.65   1510.775000
# CONJUNTO RESIDENCIAL RUC                               34455.25  11485.083333
# E1                   RUC                                   0.00      0.000000
# EDUCACION            RUC                                  31.89     31.890000
# MULTIFAMILIAR        DNI                              324688.94  17088.891579
#                      RUC                               61042.93   2260.849259
# ...

# %%
AREA_OBRA_TIPO_USO_DOC.head()
# Out:
#                                           AREA TOTAL CONSTRUIDA                \
#                                                             sum          mean
# TIPO DE USO          TIPO DOC SOLICITANTE
# CERCO                RUC                                   0.00           NaN
# COMERCIO             DNI                                 130.00    130.000000
#                      RDA                                  93.37     93.370000
#                      RUC                                9064.65   1510.775000
# CONJUNTO RESIDENCIAL RUC                               34455.25  11485.083333
#
#                                              VALOR OBRA
#                                                     sum          mean
# TIPO DE USO          TIPO DOC SOLICITANTE
# CERCO                RUC                   3.180175e+04  3.180175e+04
# COMERCIO             DNI                   1.474092e+05  1.474092e+05
#                      RDA                   9.583479e+06  9.583479e+06
# ...

# %%
AREA_OBRA_TIPO_USO_DOC.columns
# Out:
# MultiIndex([('AREA TOTAL CONSTRUIDA',  'sum'),
#             ('AREA TOTAL CONSTRUIDA', 'mean'),
#             (           'VALOR OBRA',  'sum'),
#             (           'VALOR OBRA', 'mean')],
#            )

# %%
newColumns=["_".join(levels) for levels in AREA_OBRA_TIPO_USO_DOC.columns]
newColumns
# Out:
# ['AREA TOTAL CONSTRUIDA_sum',
#  'AREA TOTAL CONSTRUIDA_mean',
#  'VALOR OBRA_sum',
#  'VALOR OBRA_mean']

# %%
AREA_OBRA_TIPO_USO_DOC.columns=newColumns

# %%
AREA_OBRA_TIPO_USO_DOC
# Out:
#                                            AREA TOTAL CONSTRUIDA_sum  \
# TIPO DE USO          TIPO DOC SOLICITANTE
# CERCO                RUC                                        0.00
# COMERCIO             DNI                                      130.00
#                      RDA                                       93.37
#                      RUC                                     9064.65
# CONJUNTO RESIDENCIAL RUC                                    34455.25
# E1                   RUC                                        0.00
# EDUCACION            RUC                                       31.89
# MULTIFAMILIAR        DNI                                   324688.94
#                      RUC                                    61042.93
# TERRENO              RUC                                       10.00
# UNIFAMILIAR          DNI                                      823.25
#                      RUC                                      172.47
#
# ...

# %%
AREA_OBRA_TIPO_USO_DOC.reset_index(inplace=True)
AREA_OBRA_TIPO_USO_DOC
# Out:
#              TIPO DE USO TIPO DOC SOLICITANTE  AREA TOTAL CONSTRUIDA_sum  \
# 0                  CERCO                  RUC                       0.00
# 1               COMERCIO                  DNI                     130.00
# 2               COMERCIO                  RDA                      93.37
# 3               COMERCIO                  RUC                    9064.65
# 4   CONJUNTO RESIDENCIAL                  RUC                   34455.25
# 5                     E1                  RUC                       0.00
# 6              EDUCACION                  RUC                      31.89
# 7          MULTIFAMILIAR                  DNI                  324688.94
# 8          MULTIFAMILIAR                  RUC                   61042.93
# 9                TERRENO                  RUC                      10.00
# 10           UNIFAMILIAR                  DNI                     823.25
# 11           UNIFAMILIAR                  RUC                     172.47
#
# ...

# %%
import os

AREA_OBRA_TIPO_USO_DOC.to_csv(os.path.join("data","Aggregated_Edifications.csv"),index=False)

# %% [markdown]
# ## 6. Guardado del output

# %%
df_ordenado
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 115          301285         150136          PE         Lima      Lima
# 116          301285         150136          PE         Lima      Lima
# 117          301285         150136          PE         Lima      Lima
# 119          301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 61           301285         150136          PE         Lima      Lima
# 63           301285         150136          PE         Lima      Lima
# 64           301285         150136          PE         Lima      Lima
# 66           301285         150136          PE         Lima      Lima
# 179          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado.to_csv(os.path.join("data","df_ordenado_Py.csv"),index=False )
df_ordenado.to_pickle(os.path.join("data","df_ordenado.pkl") )

# %%
dfPickle=pd.read_pickle(os.path.join("data","df_ordenado.pkl") )
dfCSV=pd.read_csv(os.path.join("data","df_ordenado_Py.csv") )

# %%
dfPickle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 117 entries, 0 to 179
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           117 non-null    int64
#  1   CODIGO UBIGEO            117 non-null    int64
#  2   CODIGO PAIS              117 non-null    object
#  3   DEPARTAMENTO             117 non-null    object
#  4   PROVINCIA                117 non-null    object
#  5   DISTRITO                 117 non-null    object
#  6   NOMBRE UO                117 non-null    object
#  7   GOBIERNO LOCAL           117 non-null    object
#  8   RUC GOBIERNO LOCAL       117 non-null    int64
#  9   NUMERO EXPEDIENTE        117 non-null    object
#  10  FECHA INICIO TRAMITE     79 non-null     datetime64[ns]
#  11  FECHA EMISION TRAMITE    115 non-null    datetime64[ns]
#  12  NRO RESOLUCION LICENCIA  117 non-null    object
# ...

# %%
dfCSV.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           117 non-null    int64
#  1   CODIGO UBIGEO            117 non-null    int64
#  2   CODIGO PAIS              117 non-null    object
#  3   DEPARTAMENTO             117 non-null    object
#  4   PROVINCIA                117 non-null    object
#  5   DISTRITO                 117 non-null    object
#  6   NOMBRE UO                117 non-null    object
#  7   GOBIERNO LOCAL           117 non-null    object
#  8   RUC GOBIERNO LOCAL       117 non-null    int64
#  9   NUMERO EXPEDIENTE        117 non-null    object
#  10  FECHA INICIO TRAMITE     79 non-null     object
#  11  FECHA EMISION TRAMITE    115 non-null    object
#  12  NRO RESOLUCION LICENCIA  117 non-null    object
#  13  TIPO DOC SOLICITANTE     117 non-null    object
# ...

# %%
folder="data"
fileName="Edificaciones2.xlsx"
fileToRead=os.path.join(folder,fileName)

# %%
fileName="Edificaciones2.xlsx"
fileToRead=os.path.join(folder,fileName)

dataExcel2=pd.read_excel(fileToRead, header=0)

# %%
df_ordenado2 = dataExcel2.sort_values(by="CODIGO_\nENTIDAD", ascending=True)

# %%
df_ordenado2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CODIGO_
# ENTIDAD           146 non-null    int64
#  1   CODIGO_
# UBIGEO            146 non-null    int64
#  2   CODIGO_
# PAIS              146 non-null    object
#  3   DEPARTAMENTO              146 non-null    object
#  4   PROVINCIA                 146 non-null    object
#  5   DISTRITO                  146 non-null    object
#  6   NOMBRE_UO                 146 non-null    object
#  7   GOBIERNO_LOCAL            146 non-null    object
#  8   RUC_GOBIERNO
# _LOCAL       146 non-null    int64
#  9   NUMERO_
# EXPEDIENTE        146 non-null    object
#  10  FECHA_
# INICIO_
# TRAMITE    146 non-null    object
#  11  FECHA_
# EMISION_TRAMITE    146 non-null    int64
#  12  NRO_RESOLUCION_
# LICENCIA  146 non-null    object
#  13  TIPO_DOC_
# ...

# %% [markdown]
# ## 7. Limpieza de los títulos de las columnas

# %%
df = df_ordenado2.rename(columns={
    False: 'OBRA_DEMOLICIÓN',
    'False.1': 'OBRA_REMODELACIÓN',
    'False.2': 'OBRA_AMPLIACIÓN',
    'False.3': 'OBRA_REFACCIÓN'},
    inplace=True)

# %%
df = df_ordenado2.rename(columns={
    "F": 'OBRA_DEMOLICIÓN'}, inplace=True)

# %%
# check headers
df_ordenado2.columns
# Out:
# Index(['CODIGO_\nENTIDAD', 'CODIGO_\nUBIGEO', 'CODIGO_\nPAIS', 'DEPARTAMENTO',
#        'PROVINCIA', 'DISTRITO', 'NOMBRE_UO', 'GOBIERNO_LOCAL',
#        'RUC_GOBIERNO\n_LOCAL', 'NUMERO_\nEXPEDIENTE',
#        'FECHA_\nINICIO_\nTRAMITE', 'FECHA_\nEMISION_TRAMITE',
#        'NRO_RESOLUCION_\nLICENCIA', 'TIPO_DOC_\nSOLICITANTE',
#        'NRO_DOC_\nSOLICITANTE', 'UBICACION_PREDIO', 'ZONIFICACION_\nPREDIO',
#        'TIPO_DE_USO', 'TIPO_ALTURA', 'DETALLE_ALTURA',
#        'MODALIDAD_\nAPROBACION', '\nTIPO_OBRA', 'OBRA_\nNUEVA',
#        'OBRA_DEMOLICIÓN', 'OBRA_REMODELACIÓN', 'OBRA_AMPLIACIÓN',
#        'OBRA_REFACCIÓN', 'OBRA_\nCERCO ', 'AREA_TOTAL_\nCONSTRUIDA ',
#        'VALOR_\nOBRA', 'FECHA_\nCORTE'],
#       dtype='object')

# %%
# the quasi duplicates
nColumnsI=df_ordenado2.columns[df_ordenado2.columns.str.contains('_\n')]
nColumnsI
# Out:
# Index(['CODIGO_\nENTIDAD', 'CODIGO_\nUBIGEO', 'CODIGO_\nPAIS',
#        'NUMERO_\nEXPEDIENTE', 'FECHA_\nINICIO_\nTRAMITE',
#        'FECHA_\nEMISION_TRAMITE', 'NRO_RESOLUCION_\nLICENCIA',
#        'TIPO_DOC_\nSOLICITANTE', 'NRO_DOC_\nSOLICITANTE',
#        'ZONIFICACION_\nPREDIO', 'MODALIDAD_\nAPROBACION', 'OBRA_\nNUEVA',
#        'OBRA_\nCERCO ', 'AREA_TOTAL_\nCONSTRUIDA ', 'VALOR_\nOBRA',
#        'FECHA_\nCORTE'],
#       dtype='object')

# %%
# the not quasi duplicates
df_ordenado2.columns[~df_ordenado2.columns.str.contains('_\n')]
# Out:
# Index(['DEPARTAMENTO', 'PROVINCIA', 'DISTRITO', 'NOMBRE_UO', 'GOBIERNO_LOCAL',
#        'RUC_GOBIERNO\n_LOCAL', 'UBICACION_PREDIO', 'TIPO_DE_USO',
#        'TIPO_ALTURA', 'DETALLE_ALTURA', '\nTIPO_OBRA', 'OBRA_DEMOLICIÓN',
#        'OBRA_REMODELACIÓN', 'OBRA_AMPLIACIÓN', 'OBRA_REFACCIÓN'],
#       dtype='object')

# %%
# save the last one but the first ones:
notnColumnsI=df_ordenado2.columns[~df_ordenado2.columns.str.contains('\n')][3:]
notnColumnsI
# Out:
# Index(['NOMBRE_UO', 'GOBIERNO_LOCAL', 'UBICACION_PREDIO', 'TIPO_DE_USO',
#        'TIPO_ALTURA', 'DETALLE_ALTURA', 'OBRA_DEMOLICIÓN', 'OBRA_REMODELACIÓN',
#        'OBRA_AMPLIACIÓN', 'OBRA_REFACCIÓN'],
#       dtype='object')

# %% [markdown]
# NOT N COLUMNS: Columnas que no contienen "N"

# %%
# using list comprehension
notnColumnsIa=[element.split('_') for element in notnColumnsI]
notnColumnsIa
# Out:
# [['NOMBRE', 'UO'],
#  ['GOBIERNO', 'LOCAL'],
#  ['UBICACION', 'PREDIO'],
#  ['TIPO', 'DE', 'USO'],
#  ['TIPO', 'ALTURA'],
#  ['DETALLE', 'ALTURA'],
#  ['OBRA', 'DEMOLICIÓN'],
#  ['OBRA', 'REMODELACIÓN'],
#  ['OBRA', 'AMPLIACIÓN'],
#  ['OBRA', 'REFACCIÓN']]

# %%
notnColumnsII = []

# %%
for element in notnColumnsIa:
    nElement = ' '.join(element)
    notnColumnsII.append(nElement)
notnColumnsII
# Out:
# ['NOMBRE UO',
#  'GOBIERNO LOCAL',
#  'UBICACION PREDIO',
#  'TIPO DE USO',
#  'TIPO ALTURA',
#  'DETALLE ALTURA',
#  'OBRA DEMOLICIÓN',
#  'OBRA REMODELACIÓN',
#  'OBRA AMPLIACIÓN',
#  'OBRA REFACCIÓN']

# %% [markdown]
# RUC GOBIERNO LOCAL

# %%
RUCnColumnsB=df_ordenado2.columns[df_ordenado2.columns.str.contains('RUC')]
RUCnColumnsB
# Out:
# Index(['RUC_GOBIERNO\n_LOCAL'], dtype='object')

# %%
RUCnColumnsI=[element.split('\n_') for element in RUCnColumnsB]
RUCnColumnsI
# Out:
# [['RUC_GOBIERNO', 'LOCAL']]

# %%
RUCnColumnsII = []

# %%
for element in RUCnColumnsI:
    RUCElement = ' '.join(element)
    RUCnColumnsII.append(RUCElement)
RUCnColumnsII
# Out:
# ['RUC_GOBIERNO LOCAL']

# %%
RUCnColumnsIII=[element.split('_') for element in RUCnColumnsII]
RUCnColumnsIII
# Out:
# [['RUC', 'GOBIERNO LOCAL']]

# %%
RUCnColumnsIV = []

# %%
for element in RUCnColumnsIII:
    RUCElementI = ' '.join(element)
    RUCnColumnsIV.append(RUCElementI)
RUCnColumnsIV
# Out:
# ['RUC GOBIERNO LOCAL']

# %% [markdown]
# TIPO DE OBRA

# %%
OBRAnColumnsB=df_ordenado2.columns[df_ordenado2.columns.str.contains('TIPO_OBRA')]
OBRAnColumnsB
# Out:
# Index(['\nTIPO_OBRA'], dtype='object')

# %%
OBRAnColumnsI=[element.strip('\n') for element in OBRAnColumnsB]
OBRAnColumnsI
# Out:
# ['TIPO_OBRA']

# %%
OBRAnColumnsII=[element.split('_') for element in OBRAnColumnsI]
OBRAnColumnsII
# Out:
# [['TIPO', 'OBRA']]

# %%
OBRAnColumnsIII = []

# %%
for element in OBRAnColumnsII:
    OBRAElementI = ' '.join(element)
    OBRAnColumnsIII.append(OBRAElementI)
OBRAnColumnsIII
# Out:
# ['TIPO OBRA']

# %% [markdown]
# N COLUMNS: Columnas que contienen "N"

# %%
nColumnsaI=[element.strip(' ') for element in nColumnsI]
nColumnsaI
# Out:
# ['CODIGO_\nENTIDAD',
#  'CODIGO_\nUBIGEO',
#  'CODIGO_\nPAIS',
#  'NUMERO_\nEXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE',
#  'FECHA_\nEMISION_TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA',
#  'TIPO_DOC_\nSOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE',
#  'ZONIFICACION_\nPREDIO',
#  'MODALIDAD_\nAPROBACION',
#  'OBRA_\nNUEVA',
#  'OBRA_\nCERCO',
#  'AREA_TOTAL_\nCONSTRUIDA',
#  'VALOR_\nOBRA',
#  'FECHA_\nCORTE']

# %%
nColumnsIb=[element.split('_\n') for element in nColumnsaI]
nColumnsIb
# Out:
# [['CODIGO', 'ENTIDAD'],
#  ['CODIGO', 'UBIGEO'],
#  ['CODIGO', 'PAIS'],
#  ['NUMERO', 'EXPEDIENTE'],
#  ['FECHA', 'INICIO', 'TRAMITE'],
#  ['FECHA', 'EMISION_TRAMITE'],
#  ['NRO_RESOLUCION', 'LICENCIA'],
#  ['TIPO_DOC', 'SOLICITANTE'],
#  ['NRO_DOC', 'SOLICITANTE'],
#  ['ZONIFICACION', 'PREDIO'],
#  ['MODALIDAD', 'APROBACION'],
#  ['OBRA', 'NUEVA'],
#  ['OBRA', 'CERCO'],
#  ['AREA_TOTAL', 'CONSTRUIDA'],
#  ['VALOR', 'OBRA'],
#  ['FECHA', 'CORTE']]

# %%
nColumnsII = []

# %%
for element in nColumnsIb:
    nElementII = ' '.join(element)
    nColumnsII.append(nElementII)
nColumnsII
# Out:
# ['CODIGO ENTIDAD',
#  'CODIGO UBIGEO',
#  'CODIGO PAIS',
#  'NUMERO EXPEDIENTE',
#  'FECHA INICIO TRAMITE',
#  'FECHA EMISION_TRAMITE',
#  'NRO_RESOLUCION LICENCIA',
#  'TIPO_DOC SOLICITANTE',
#  'NRO_DOC SOLICITANTE',
#  'ZONIFICACION PREDIO',
#  'MODALIDAD APROBACION',
#  'OBRA NUEVA',
#  'OBRA CERCO',
#  'AREA_TOTAL CONSTRUIDA',
#  'VALOR OBRA',
#  'FECHA CORTE']

# %%
nColumnsIII=[element.split('_') for element in nColumnsII]
nColumnsIII
# Out:
# [['CODIGO ENTIDAD'],
#  ['CODIGO UBIGEO'],
#  ['CODIGO PAIS'],
#  ['NUMERO EXPEDIENTE'],
#  ['FECHA INICIO TRAMITE'],
#  ['FECHA EMISION', 'TRAMITE'],
#  ['NRO', 'RESOLUCION LICENCIA'],
#  ['TIPO', 'DOC SOLICITANTE'],
#  ['NRO', 'DOC SOLICITANTE'],
#  ['ZONIFICACION PREDIO'],
#  ['MODALIDAD APROBACION'],
#  ['OBRA NUEVA'],
#  ['OBRA CERCO'],
#  ['AREA', 'TOTAL CONSTRUIDA'],
#  ['VALOR OBRA'],
#  ['FECHA CORTE']]

# %%
nColumnsIV = []

# %%
for element in nColumnsIII:
    elementnI = ' '.join(element)
    nColumnsIV.append(elementnI)
nColumnsIV
# Out:
# ['CODIGO ENTIDAD',
#  'CODIGO UBIGEO',
#  'CODIGO PAIS',
#  'NUMERO EXPEDIENTE',
#  'FECHA INICIO TRAMITE',
#  'FECHA EMISION TRAMITE',
#  'NRO RESOLUCION LICENCIA',
#  'TIPO DOC SOLICITANTE',
#  'NRO DOC SOLICITANTE',
#  'ZONIFICACION PREDIO',
#  'MODALIDAD APROBACION',
#  'OBRA NUEVA',
#  'OBRA CERCO',
#  'AREA TOTAL CONSTRUIDA',
#  'VALOR OBRA',
#  'FECHA CORTE']

# %%
changeI = {old:new for old,new in zip(notnColumnsI, notnColumnsII)}
changeI
# Out:
# {'NOMBRE_UO': 'NOMBRE UO',
#  'GOBIERNO_LOCAL': 'GOBIERNO LOCAL',
#  'UBICACION_PREDIO': 'UBICACION PREDIO',
#  'TIPO_DE_USO': 'TIPO DE USO',
#  'TIPO_ALTURA': 'TIPO ALTURA',
#  'DETALLE_ALTURA': 'DETALLE ALTURA',
#  'OBRA_DEMOLICIÓN': 'OBRA DEMOLICIÓN',
#  'OBRA_REMODELACIÓN': 'OBRA REMODELACIÓN',
#  'OBRA_AMPLIACIÓN': 'OBRA AMPLIACIÓN',
#  'OBRA_REFACCIÓN': 'OBRA REFACCIÓN'}

# %%
changeII={old:new for old,new in zip(nColumnsI,nColumnsIV)}
changeII
# Out:
# {'CODIGO_\nENTIDAD': 'CODIGO ENTIDAD',
#  'CODIGO_\nUBIGEO': 'CODIGO UBIGEO',
#  'CODIGO_\nPAIS': 'CODIGO PAIS',
#  'NUMERO_\nEXPEDIENTE': 'NUMERO EXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE': 'FECHA INICIO TRAMITE',
#  'FECHA_\nEMISION_TRAMITE': 'FECHA EMISION TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA': 'NRO RESOLUCION LICENCIA',
#  'TIPO_DOC_\nSOLICITANTE': 'TIPO DOC SOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE': 'NRO DOC SOLICITANTE',
#  'ZONIFICACION_\nPREDIO': 'ZONIFICACION PREDIO',
#  'MODALIDAD_\nAPROBACION': 'MODALIDAD APROBACION',
#  'OBRA_\nNUEVA': 'OBRA NUEVA',
#  'OBRA_\nCERCO ': 'OBRA CERCO',
#  'AREA_TOTAL_\nCONSTRUIDA ': 'AREA TOTAL CONSTRUIDA',
#  'VALOR_\nOBRA': 'VALOR OBRA',
#  'FECHA_\nCORTE': 'FECHA CORTE'}

# %%
changeIII={old:new for old,new in zip(OBRAnColumnsB,OBRAnColumnsIII)}
changeIII
# Out:
# {'\nTIPO_OBRA': 'TIPO OBRA'}

# %%
changeIV={old:new for old,new in zip(RUCnColumnsB,RUCnColumnsIV)}
changeIV
# Out:
# {'RUC_GOBIERNO\n_LOCAL': 'RUC GOBIERNO LOCAL'}

# %%
changeI.update(changeII)
changeI
# Out:
# {'NOMBRE_UO': 'NOMBRE UO',
#  'GOBIERNO_LOCAL': 'GOBIERNO LOCAL',
#  'UBICACION_PREDIO': 'UBICACION PREDIO',
#  'TIPO_DE_USO': 'TIPO DE USO',
#  'TIPO_ALTURA': 'TIPO ALTURA',
#  'DETALLE_ALTURA': 'DETALLE ALTURA',
#  'OBRA_DEMOLICIÓN': 'OBRA DEMOLICIÓN',
#  'OBRA_REMODELACIÓN': 'OBRA REMODELACIÓN',
#  'OBRA_AMPLIACIÓN': 'OBRA AMPLIACIÓN',
#  'OBRA_REFACCIÓN': 'OBRA REFACCIÓN',
#  'CODIGO_\nENTIDAD': 'CODIGO ENTIDAD',
#  'CODIGO_\nUBIGEO': 'CODIGO UBIGEO',
#  'CODIGO_\nPAIS': 'CODIGO PAIS',
#  'NUMERO_\nEXPEDIENTE': 'NUMERO EXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE': 'FECHA INICIO TRAMITE',
#  'FECHA_\nEMISION_TRAMITE': 'FECHA EMISION TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA': 'NRO RESOLUCION LICENCIA',
#  'TIPO_DOC_\nSOLICITANTE': 'TIPO DOC SOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE': 'NRO DOC SOLICITANTE',
#  'ZONIFICACION_\nPREDIO': 'ZONIFICACION PREDIO',
#  'MODALIDAD_\nAPROBACION': 'MODALIDAD APROBACION',
#  'OBRA_\nNUEVA': 'OBRA NUEVA',
#  'OBRA_\nCERCO ': 'OBRA CERCO',
# ...

# %%
changeI.update(changeIII)
changeI
# Out:
# {'NOMBRE_UO': 'NOMBRE UO',
#  'GOBIERNO_LOCAL': 'GOBIERNO LOCAL',
#  'UBICACION_PREDIO': 'UBICACION PREDIO',
#  'TIPO_DE_USO': 'TIPO DE USO',
#  'TIPO_ALTURA': 'TIPO ALTURA',
#  'DETALLE_ALTURA': 'DETALLE ALTURA',
#  'OBRA_DEMOLICIÓN': 'OBRA DEMOLICIÓN',
#  'OBRA_REMODELACIÓN': 'OBRA REMODELACIÓN',
#  'OBRA_AMPLIACIÓN': 'OBRA AMPLIACIÓN',
#  'OBRA_REFACCIÓN': 'OBRA REFACCIÓN',
#  'CODIGO_\nENTIDAD': 'CODIGO ENTIDAD',
#  'CODIGO_\nUBIGEO': 'CODIGO UBIGEO',
#  'CODIGO_\nPAIS': 'CODIGO PAIS',
#  'NUMERO_\nEXPEDIENTE': 'NUMERO EXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE': 'FECHA INICIO TRAMITE',
#  'FECHA_\nEMISION_TRAMITE': 'FECHA EMISION TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA': 'NRO RESOLUCION LICENCIA',
#  'TIPO_DOC_\nSOLICITANTE': 'TIPO DOC SOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE': 'NRO DOC SOLICITANTE',
#  'ZONIFICACION_\nPREDIO': 'ZONIFICACION PREDIO',
#  'MODALIDAD_\nAPROBACION': 'MODALIDAD APROBACION',
#  'OBRA_\nNUEVA': 'OBRA NUEVA',
#  'OBRA_\nCERCO ': 'OBRA CERCO',
# ...

# %%
changeI.update(changeIV)
changeI
# Out:
# {'NOMBRE_UO': 'NOMBRE UO',
#  'GOBIERNO_LOCAL': 'GOBIERNO LOCAL',
#  'UBICACION_PREDIO': 'UBICACION PREDIO',
#  'TIPO_DE_USO': 'TIPO DE USO',
#  'TIPO_ALTURA': 'TIPO ALTURA',
#  'DETALLE_ALTURA': 'DETALLE ALTURA',
#  'OBRA_DEMOLICIÓN': 'OBRA DEMOLICIÓN',
#  'OBRA_REMODELACIÓN': 'OBRA REMODELACIÓN',
#  'OBRA_AMPLIACIÓN': 'OBRA AMPLIACIÓN',
#  'OBRA_REFACCIÓN': 'OBRA REFACCIÓN',
#  'CODIGO_\nENTIDAD': 'CODIGO ENTIDAD',
#  'CODIGO_\nUBIGEO': 'CODIGO UBIGEO',
#  'CODIGO_\nPAIS': 'CODIGO PAIS',
#  'NUMERO_\nEXPEDIENTE': 'NUMERO EXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE': 'FECHA INICIO TRAMITE',
#  'FECHA_\nEMISION_TRAMITE': 'FECHA EMISION TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA': 'NRO RESOLUCION LICENCIA',
#  'TIPO_DOC_\nSOLICITANTE': 'TIPO DOC SOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE': 'NRO DOC SOLICITANTE',
#  'ZONIFICACION_\nPREDIO': 'ZONIFICACION PREDIO',
#  'MODALIDAD_\nAPROBACION': 'MODALIDAD APROBACION',
#  'OBRA_\nNUEVA': 'OBRA NUEVA',
#  'OBRA_\nCERCO ': 'OBRA CERCO',
# ...

# %%
changeI
# Out:
# {'NOMBRE_UO': 'NOMBRE UO',
#  'GOBIERNO_LOCAL': 'GOBIERNO LOCAL',
#  'UBICACION_PREDIO': 'UBICACION PREDIO',
#  'TIPO_DE_USO': 'TIPO DE USO',
#  'TIPO_ALTURA': 'TIPO ALTURA',
#  'DETALLE_ALTURA': 'DETALLE ALTURA',
#  'OBRA_DEMOLICIÓN': 'OBRA DEMOLICIÓN',
#  'OBRA_REMODELACIÓN': 'OBRA REMODELACIÓN',
#  'OBRA_AMPLIACIÓN': 'OBRA AMPLIACIÓN',
#  'OBRA_REFACCIÓN': 'OBRA REFACCIÓN',
#  'CODIGO_\nENTIDAD': 'CODIGO ENTIDAD',
#  'CODIGO_\nUBIGEO': 'CODIGO UBIGEO',
#  'CODIGO_\nPAIS': 'CODIGO PAIS',
#  'NUMERO_\nEXPEDIENTE': 'NUMERO EXPEDIENTE',
#  'FECHA_\nINICIO_\nTRAMITE': 'FECHA INICIO TRAMITE',
#  'FECHA_\nEMISION_TRAMITE': 'FECHA EMISION TRAMITE',
#  'NRO_RESOLUCION_\nLICENCIA': 'NRO RESOLUCION LICENCIA',
#  'TIPO_DOC_\nSOLICITANTE': 'TIPO DOC SOLICITANTE',
#  'NRO_DOC_\nSOLICITANTE': 'NRO DOC SOLICITANTE',
#  'ZONIFICACION_\nPREDIO': 'ZONIFICACION PREDIO',
#  'MODALIDAD_\nAPROBACION': 'MODALIDAD APROBACION',
#  'OBRA_\nNUEVA': 'OBRA NUEVA',
#  'OBRA_\nCERCO ': 'OBRA CERCO',
# ...

# %%
df_ordenado2.rename(columns=changeI,inplace=True)
df_ordenado2.head()
# Out:
#     CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0           301285         150136          PE         Lima      Lima
# 93          301285         150136          PE         Lima      Lima
# 94          301285         150136          PE         Lima      Lima
# 95          301285         150136          PE         Lima      Lima
# 96          301285         150136          PE         Lima      Lima
#
#       DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0   San Miguel  Subgerencia de Obras Privadas     San Miguel
# 93  San Miguel  Subgerencia de Obras Privadas     San Miguel
# 94  San Miguel  Subgerencia de Obras Privadas     San Miguel
# 95  San Miguel  Subgerencia de Obras Privadas     San Miguel
# 96  San Miguel  Subgerencia de Obras Privadas     San Miguel
#
#     RUC GOBIERNO LOCAL NUMERO EXPEDIENTE  ...  \
# 0          20131372184        13742-2020  ...
# 93         20131372184         6813-2021  ...
# ...

# %% [markdown]
# Se actualizaron los valores de los títulos de las columnas de la data.

# %% [markdown]
# ## 8. Limpieza de los datos

# %%
df_ordenado2.columns
# Out:
# Index(['CODIGO ENTIDAD', 'CODIGO UBIGEO', 'CODIGO PAIS', 'DEPARTAMENTO',
#        'PROVINCIA', 'DISTRITO', 'NOMBRE UO', 'GOBIERNO LOCAL',
#        'RUC GOBIERNO LOCAL', 'NUMERO EXPEDIENTE', 'FECHA INICIO TRAMITE',
#        'FECHA EMISION TRAMITE', 'NRO RESOLUCION LICENCIA',
#        'TIPO DOC SOLICITANTE', 'NRO DOC SOLICITANTE', 'UBICACION PREDIO',
#        'ZONIFICACION PREDIO', 'TIPO DE USO', 'TIPO ALTURA', 'DETALLE ALTURA',
#        'MODALIDAD APROBACION', 'TIPO OBRA', 'OBRA NUEVA', 'OBRA DEMOLICIÓN',
#        'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN', 'OBRA CERCO',
#        'AREA TOTAL CONSTRUIDA', 'VALOR OBRA', 'FECHA CORTE'],
#       dtype='object')

# %% [markdown]
# Código Entidad

# %%
df_ordenado2['CODIGO ENTIDAD'].value_counts(dropna=False).sort_index()
# Out:
# 301285    146
# Name: CODIGO ENTIDAD, dtype: int64

# %% [markdown]
# Código Ubigeo

# %%
df_ordenado2['CODIGO UBIGEO'].value_counts(dropna=False).sort_index()
# Out:
# 150136    146
# Name: CODIGO UBIGEO, dtype: int64

# %% [markdown]
# Código País

# %%
df_ordenado2['CODIGO PAIS'].value_counts(dropna=False).sort_index()
# Out:
# PE    146
# Name: CODIGO PAIS, dtype: int64

# %% [markdown]
# Departamento

# %%
df_ordenado2['DEPARTAMENTO'].value_counts(dropna=False).sort_index()
# Out:
# Lima    146
# Name: DEPARTAMENTO, dtype: int64

# %% [markdown]
# Provincia

# %%
df_ordenado2['PROVINCIA'].value_counts(dropna=False).sort_index()
# Out:
# Lima    146
# Name: PROVINCIA, dtype: int64

# %% [markdown]
# Distrito

# %%
df_ordenado2['DISTRITO'].value_counts(dropna=False).sort_index()
# Out:
# San Miguel    146
# Name: DISTRITO, dtype: int64

# %% [markdown]
# Nombre Unidad Orgánica

# %%
df_ordenado2['NOMBRE UO'].value_counts(dropna=False).sort_index()
# Out:
# Subgerencia de Obras Privadas    146
# Name: NOMBRE UO, dtype: int64

# %% [markdown]
# Gobierno Local

# %%
df_ordenado2['GOBIERNO LOCAL'].value_counts(dropna=False).sort_index()
# Out:
# San Miguel    146
# Name: GOBIERNO LOCAL, dtype: int64

# %% [markdown]
# RUC Gobierno Local

# %%
df_ordenado2['RUC GOBIERNO LOCAL'].value_counts(dropna=False).sort_index()
# Out:
# 20131372184    146
# Name: RUC GOBIERNO LOCAL, dtype: int64

# %% [markdown]
# Número Expediente

# %%
df_ordenado2['NUMERO EXPEDIENTE'].value_counts(dropna=False).sort_index()
# Out:
# 00295-2021    1
# 00296-2021    1
# 00861-2021    1
# 0152-2021     1
# 01713-2021    1
#              ..
# 950-2021      1
# 9841-2020     1
# 994-2021      1
# Ago-21        1
# Oct-21        1
# Name: NUMERO EXPEDIENTE, Length: 145, dtype: int64

# %% [markdown]
# Número de la resolución de licencia

# %%
df_ordenado2['NRO RESOLUCION LICENCIA'] = df_ordenado2['NRO RESOLUCION LICENCIA'].astype(str)

# %%
df_ordenado2['NRO RESOLUCION LICENCIA'].value_counts(dropna=False).sort_index()
# Out:
# 001-2021     1
# 003-2021     1
# 089-2021     1
# 1005-2021    1
# 103-2021     1
#             ..
# 938-2021     1
# 939-2021     1
# 944-2021     1
# 967-2021     1
# 984-2021     1
# Name: NRO RESOLUCION LICENCIA, Length: 145, dtype: int64

# %% [markdown]
# Tipo Documento Solicitante

# %%
df_ordenado2['TIPO DOC SOLICITANTE'].value_counts(dropna=False).sort_index()
# Out:
# CZ       1
# DNI     58
# DNI      6
# RDA      2
# RDM      3
# RUC     73
# RUC      3
# Name: TIPO DOC SOLICITANTE, dtype: int64

# %%
df_ordenado2['TIPO DOC SOLICITANTE'] = df_ordenado2['TIPO DOC SOLICITANTE'].str.strip()

# %%
df_ordenado2['TIPO DOC SOLICITANTE'].value_counts(dropna=False).sort_index()
# Out:
# CZ      1
# DNI    64
# RDA     2
# RDM     3
# RUC    76
# Name: TIPO DOC SOLICITANTE, dtype: int64

# %% [markdown]
# Ubicación Predio

# %%
df_ordenado2['UBICACION PREDIO'] = df_ordenado2['UBICACION PREDIO'].str.strip()

# %%
df_ordenado2['UBICACION PREDIO'].value_counts(dropna=False).sort_index()
# Out:
# - - -                                                                                                  1
# - AV. ELMER FAUCETT 320 - C - -                                                                        1
# - LA PAZ                                                                               2337 - - - -    1
# AV ALTO VENEZUELA 5415 - A A -                                                                         1
# AV ANDRES RAZURI 305 - - - -                                                                           1
#                                                                                                       ..
# PASAJE ISLA DE CORCONVADO - - J3 19 -                                                                  1
# PASAJE LOS LIRIOS 180 - - - -                                                                          1
# PASAJE MARGARITA PRAXIDES 117-119 - J2-2 20 -                                                          1
# ...

# %% [markdown]
# Zonificación Predio

# %%
df_ordenado2['ZONIFICACION PREDIO'].value_counts(dropna=False).sort_index()
# Out:
# C5          1
# CM          5
# CM          1
# CV          1
# CV, RDM     1
# CZ          8
# CZ,RDA      1
# E1          1
# R4          1
# RDA        18
# RDA         1
# RDM        98
# RDM         7
# ZTP         1
# NaN         1
# Name: ZONIFICACION PREDIO, dtype: int64

# %%
df_ordenado2['ZONIFICACION PREDIO'] = df_ordenado2['ZONIFICACION PREDIO'].str.strip()

# %%
df_ordenado2['ZONIFICACION PREDIO'].value_counts(dropna=False).sort_index()
# Out:
# C5           1
# CM           6
# CV           1
# CV, RDM      1
# CZ           8
# CZ,RDA       1
# E1           1
# R4           1
# RDA         19
# RDM        105
# ZTP          1
# NaN          1
# Name: ZONIFICACION PREDIO, dtype: int64

# %% [markdown]
# Tipo de Uso

# %%
USOB= df_ordenado2['TIPO DE USO'].value_counts(dropna=False).sort_index()

# %%
df_ordenado2['TIPO DE USO'] = df_ordenado2['TIPO DE USO'].str.strip()

# %%
df_ordenado2['TIPO DE USO'].value_counts(dropna=False).sort_index()
# Out:
# COLEGIO                              1
# COMERCIO                             9
# CONJUNTO RESIDENCIAL                 3
# CONJUNTO RESIDENCIAL - COMERCIO      1
# EVENTOS Y/O CULTURALES               1
# MARINA DE GUERRA                     1
# RESIDENCIAL                          1
# VIIVENDA UNIFAMILIAR                 2
# VIVENDA UNIFAMILIAR                  1
# VIVIENDA MULTIFAMILIAR              63
# VIVIENDA MULTIFAMILIAR- COMERCIO     1
# VIVIENDA MULTIIFAMILIAR              1
# VIVIENDA UNIFAMILIAR                60
# NaN                                  1
# Name: TIPO DE USO, dtype: int64

# %%
def UNIFORMIDAD2(FAMILIA2):
    if pd.isnull(FAMILIA2):
        return FAMILIA2
    FAMILIA2 = FAMILIA2.upper()
    if 'UNIFAMILIAR' in FAMILIA2:
        return 'UNIFAMILIAR'
    elif 'MULTIFAMILIAR' in FAMILIA2:
        return 'MULTIFAMILIAR'
    elif "COMERCIO" in FAMILIA2:
        return "COMERCIO"
    else:
        return FAMILIA2

df_ordenado2['TIPO DE USO NORMALIZADO'] = df_ordenado2['TIPO DE USO'].apply(UNIFORMIDAD2)

USO1b= df_ordenado2['TIPO DE USO NORMALIZADO'].value_counts(dropna=False).sort_index()
USO1b
# Out:
# COLEGIO                     1
# COMERCIO                   10
# CONJUNTO RESIDENCIAL        3
# EVENTOS Y/O CULTURALES      1
# MARINA DE GUERRA            1
# MULTIFAMILIAR              64
# RESIDENCIAL                 1
# UNIFAMILIAR                63
# VIVIENDA MULTIIFAMILIAR     1
# NaN                         1
# Name: TIPO DE USO NORMALIZADO, dtype: int64

# %%
df_ordenado2['TIPO DE USO NORMALIZADO']
# Out:
# 0                MULTIFAMILIAR
# 93                 UNIFAMILIAR
# 94                 UNIFAMILIAR
# 95                 UNIFAMILIAR
# 96                 UNIFAMILIAR
#                 ...
# 50     VIVIENDA MULTIIFAMILIAR
# 51                 UNIFAMILIAR
# 52               MULTIFAMILIAR
# 36                    COMERCIO
# 145                UNIFAMILIAR
# Name: TIPO DE USO NORMALIZADO, Length: 146, dtype: object

# %%
df_ordenado2['TIPO DE USO'] = df_ordenado2['TIPO DE USO NORMALIZADO']
df_ordenado2
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 93           301285         150136          PE         Lima      Lima
# 94           301285         150136          PE         Lima      Lima
# 95           301285         150136          PE         Lima      Lima
# 96           301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 50           301285         150136          PE         Lima      Lima
# 51           301285         150136          PE         Lima      Lima
# 52           301285         150136          PE         Lima      Lima
# 36           301285         150136          PE         Lima      Lima
# 145          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado2 = df_ordenado2.drop('TIPO DE USO NORMALIZADO', axis=1)

# %% [markdown]
# Tipo de Altura

# %%
df_ordenado2['TIPO ALTURA'] = df_ordenado2['TIPO ALTURA'].str.strip()

# %%
df_ordenado2['TIPO ALTURA'].value_counts(dropna=False).sort_index()
# Out:
# CERCO      1
# PISO       8
# PISOS    134
# NaN        3
# Name: TIPO ALTURA, dtype: int64

# %% [markdown]
# Detalle Altura

# %%
df_ordenado2['DETALLE ALTURA'] = df_ordenado2['DETALLE ALTURA'].astype(str)

# %%
df_ordenado2['DETALLE ALTURA'].value_counts(dropna=False).sort_index()
# Out:
# 1 ER PISO                          1
# 1 PISO                            13
# 1 PISO                             2
# 1 PSIOS                            1
# 1 SEMISOTANO + 6 PISOS+ AZOTEA     1
# 12 PISOS                           1
# 14 PISOS +A ZOTEA                  1
# 15 PISOS + AZOTEA                  2
# 16 PISOS                           1
# 16 PISOS                           1
# 16 PISOS + AZOTEA                  1
# 16 PISOS+2 SOTANOS + AZOTEA        1
# 17 PISOS +4 SOTANOS +AZOTEA        1
# 18 PISOS + 3 SOTANOS               1
# 2 PISOS                           14
# 2 PISOS                            8
# 2 PISOS + AZOTEA                   3
# 2 PISOS + AZOTEA                   1
# 2 PISOS +AZOTEA                    1
# 2 PISOS+ AZOTEA                    1
# 2 PISOS+AZOTEA                     1
# 2 SOTANOS + 13 PISOS + AZOTEA      1
# 2 SOTANOS + 15 PISOS + AZOTEA      1
# 2 SOTANOS + 6 PISOS + AZOTEA       1
# 2 SOTANOS+16 PISOS                 1
# ...

# %%
df_ordenado2['DETALLE ALTURA'] = df_ordenado2['DETALLE ALTURA'].str.strip()

# %%
df_ordenado2['DETALLE ALTURA'].value_counts(dropna=False).sort_index()
# Out:
# 1 ER PISO                          1
# 1 PISO                            15
# 1 PSIOS                            1
# 1 SEMISOTANO + 6 PISOS+ AZOTEA     1
# 12 PISOS                           1
# 14 PISOS +A ZOTEA                  1
# 15 PISOS + AZOTEA                  2
# 16 PISOS                           2
# 16 PISOS + AZOTEA                  1
# 16 PISOS+2 SOTANOS + AZOTEA        1
# 17 PISOS +4 SOTANOS +AZOTEA        1
# 18 PISOS + 3 SOTANOS               1
# 2 PISOS                           22
# 2 PISOS + AZOTEA                   4
# 2 PISOS +AZOTEA                    1
# 2 PISOS+ AZOTEA                    1
# 2 PISOS+AZOTEA                     1
# 2 SOTANOS + 13 PISOS + AZOTEA      1
# 2 SOTANOS + 15 PISOS + AZOTEA      1
# 2 SOTANOS + 6 PISOS + AZOTEA       1
# 2 SOTANOS+16 PISOS                 1
# 20 PISOS + 4 SOTANOS + AZOTEA      1
# 20 PISOS + AZOTEA                  1
# 20 PISOS+ AZOTEA                   1
# 3 PISO + AZOTEA                    1
# ...

# %%
def ALTURA2(ALTURA2):
    if not isinstance(ALTURA2, str):
        ALTURA2 = str(ALTURA2)
    if '1P' in ALTURA2:
        return '1 PISO'
    elif '2P' in ALTURA2:
        return '2 PISOS'
    elif "3P" in ALTURA2:
        return "3 PISOS"
    elif "4P" in ALTURA2:
        return "4 PISOS"
    elif "5P" in ALTURA2:
        return "5 PISOS"
    elif '1 PISO' in ALTURA2:
        return '1 PISO'
    elif '2 PISO' in ALTURA2:
        return '2 PISOS'
    elif "3 PISO" in ALTURA2:
        return "3 PISOS"
    elif "4 PISO" in ALTURA2:
        return "4 PISOS"
    elif "5 PISO" in ALTURA2:
        return "5 PISOS"
    elif "6P" in ALTURA2:
        return "6 PISOS"
    elif "6 PISO" in ALTURA2:
        return "6 PISOS"
    elif "7 PISO" in ALTURA2:
        return "7 PISOS"
    elif "7P" in ALTURA2:
        return "7 PISOS"
    elif "8 PISO" in ALTURA2:
        return "8 PISOS"
    elif "8P" in ALTURA2:
        return "8 PISOS"
    elif "9 PISO" in ALTURA2:
        return "9 PISOS"
    elif "9P" in ALTURA2:
        return "9 PISOS"
    elif "10 PISO" in ALTURA2:
        return "10 PISOS"
    elif "10P" in ALTURA2:
        return "10 PISOS"
    elif "11 PISO" in ALTURA2:
        return "11 PISOS"
    elif "False" in ALTURA2:
        return ""
    elif "20 PISO" in ALTURA2:
        return "20 PISOS"
    elif "1 ER PISO" in ALTURA2:
        return "1 PISO"
    elif "1 PSIOS" in ALTURA2:
        return "1 PISO"
    elif "3 PSISO" in ALTURA2:
        return "3 PISOS"
    elif "CERCO PERIMETRICO" in ALTURA2:
        return "1 PISO"
    elif "NIVEL -0.60 A +0.60" in ALTURA2:
        return ""
    else:
        return ALTURA2

df_ordenado2['DETALLE ALTURA NORMALIZADO'] = df_ordenado2['DETALLE ALTURA'].apply(ALTURA2)

df_ordenado2['DETALLE ALTURA'].value_counts(dropna=False).sort_index()
# Out:
# 1 ER PISO                          1
# 1 PISO                            15
# 1 PSIOS                            1
# 1 SEMISOTANO + 6 PISOS+ AZOTEA     1
# 12 PISOS                           1
# 14 PISOS +A ZOTEA                  1
# 15 PISOS + AZOTEA                  2
# 16 PISOS                           2
# 16 PISOS + AZOTEA                  1
# 16 PISOS+2 SOTANOS + AZOTEA        1
# 17 PISOS +4 SOTANOS +AZOTEA        1
# 18 PISOS + 3 SOTANOS               1
# 2 PISOS                           22
# 2 PISOS + AZOTEA                   4
# 2 PISOS +AZOTEA                    1
# 2 PISOS+ AZOTEA                    1
# 2 PISOS+AZOTEA                     1
# 2 SOTANOS + 13 PISOS + AZOTEA      1
# 2 SOTANOS + 15 PISOS + AZOTEA      1
# 2 SOTANOS + 6 PISOS + AZOTEA       1
# 2 SOTANOS+16 PISOS                 1
# 20 PISOS + 4 SOTANOS + AZOTEA      1
# 20 PISOS + AZOTEA                  1
# 20 PISOS+ AZOTEA                   1
# 3 PISO + AZOTEA                    1
# ...

# %%
df_ordenado2['DETALLE ALTURA'] = df_ordenado2['DETALLE ALTURA NORMALIZADO']
df_ordenado2
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 93           301285         150136          PE         Lima      Lima
# 94           301285         150136          PE         Lima      Lima
# 95           301285         150136          PE         Lima      Lima
# 96           301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 50           301285         150136          PE         Lima      Lima
# 51           301285         150136          PE         Lima      Lima
# 52           301285         150136          PE         Lima      Lima
# 36           301285         150136          PE         Lima      Lima
# 145          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado2 = df_ordenado2.drop('DETALLE ALTURA NORMALIZADO', axis=1)

# %% [markdown]
# Modalidad Aprobación

# %%
df_ordenado2['MODALIDAD APROBACION'] = df_ordenado2['MODALIDAD APROBACION'].astype(str)

# %%
df_ordenado2['MODALIDAD APROBACION'].value_counts(dropna=False).sort_index()
# Out:
# A      57
# B      43
# C      45
# nan     1
# Name: MODALIDAD APROBACION, dtype: int64

# %%
def APROBACION2(MODALIDAD2):
    if 'C' in MODALIDAD2:
        return 'C'
    if "A" in MODALIDAD2:
        return "A"
    else:
        return MODALIDAD2

df_ordenado2['MODALIDAD APROBACION NORMALIZADO'] = df_ordenado2['MODALIDAD APROBACION'].apply(APROBACION2)

df_ordenado2['MODALIDAD APROBACION NORMALIZADO'].value_counts(dropna=False).sort_index()
# Out:
# A      57
# B      43
# C      45
# nan     1
# Name: MODALIDAD APROBACION NORMALIZADO, dtype: int64

# %%
df_ordenado2['MODALIDAD APROBACION'] = df_ordenado2['MODALIDAD APROBACION NORMALIZADO']
df_ordenado2
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 93           301285         150136          PE         Lima      Lima
# 94           301285         150136          PE         Lima      Lima
# 95           301285         150136          PE         Lima      Lima
# 96           301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 50           301285         150136          PE         Lima      Lima
# 51           301285         150136          PE         Lima      Lima
# 52           301285         150136          PE         Lima      Lima
# 36           301285         150136          PE         Lima      Lima
# 145          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado2 = df_ordenado2.drop('MODALIDAD APROBACION NORMALIZADO', axis=1)

# %% [markdown]
# Tipo de Obra

# %%
df_ordenado2['TIPO OBRA'] = df_ordenado2['TIPO OBRA'].astype(str)

# %%
df_ordenado2['TIPO OBRA'].value_counts(dropna=False).sort_index()
# Out:
# 0BRA NUEVA                                             1
# AMPLIACION                                            15
# AMPLIACION - REMODELACION                              2
# AMPLIACION Y DEMOLICION PARCIAL                        1
# AMPLIACION Y DEMOLICION PARCIAL                        2
# AMPLIACION Y REMODELACION                              5
# AMPLIACION Y REMODELACION                              1
# AMPLIACION-REMODELACION-DEMOLICION                     1
# APLIACION Y REMODELACION                               1
# CERCO                                                  2
# CERCO FRONTAL                                          1
# CERCO PERMITERICO                                      1
# DEMOLICION                                             6
# DEMOLICION PARCIAL-AMPLIACION-REMODELACION             1
# DEMOLICION TOTAL                                      15
# DEMOLICION TOTAL                                      28
# ...

# %%
df_ordenado2['TIPO OBRA'] = df_ordenado2['TIPO OBRA'].str.strip()

# %%
df_ordenado2['TIPO OBRA'].value_counts(dropna=False).sort_index()
# Out:
# 0BRA NUEVA                                            1
# AMPLIACION                                           15
# AMPLIACION - REMODELACION                             2
# AMPLIACION Y DEMOLICION PARCIAL                       3
# AMPLIACION Y REMODELACION                             6
# AMPLIACION-REMODELACION-DEMOLICION                    1
# APLIACION Y REMODELACION                              1
# CERCO                                                 2
# CERCO FRONTAL                                         1
# CERCO PERMITERICO                                     1
# DEMOLICION                                            6
# DEMOLICION PARCIAL-AMPLIACION-REMODELACION            1
# DEMOLICION TOTAL                                     43
# DEMOLICION TOTAl                                      3
# DEMOLICION/AMPLIAACION Y REMODELACION                 1
# EDIFICACION NEUEVA                                    1
# EDIFICACION NUEVA                                     6
# ...

# %%
def OBRA2(DETALLE3):
    if 'MOD. DE PROYECTO' in DETALLE3:
        return 'LICENCIA DE MODIFICACION DE PROYECTO'
    elif 'LICENCIA DE DEMOLICION' in DETALLE3:
        return 'LICENCIA DE DEMOLICION TOTAL'
    elif "LICENCIA DEMOLICION TOTAL" in DETALLE3:
        return "LICENCIA DE DEMOLICION TOTAL"
    elif "LICENCIA OBRA NUEVA - ETAPA 2" in DETALLE3:
        return "LICENCIA OBRA NUEVA ETAPA 2"
    elif "LICENCIA OBRA NUEVA - ETAPA 3" in DETALLE3:
        return "LICENCIA OBRA NUEVA ETAPA 3"
    elif "LICENCIA OBRA NUEVA - ETAPA 4" in DETALLE3:
        return "LICENCIA OBRA NUEVA ETAPA 4"
    elif "OLICION TOTAL" in DETALLE3:
        return "LICENCIA DE DEMOLICION TOTAL"
    elif "AMPLIACIÓN Y REMODELACIÓN" in DETALLE3:
        return "LICENCIA DE AMPLIACION - REMODELACION"
    elif "AMPLIACIÓN/REMODELACIÓN" in DETALLE3:
        return "LICENCIA DE AMPLIACION - REMODELACION"
    elif "AMPLIACION - REMODELACION - DEMOLICION PARCIAL" in DETALLE3:
        return "LICENCIA DE AMPLIACIÓN-REMODELACIÓN Y DEMOLICIÓN PARCIAL"
    elif "LICENCIA AMP,REM,DEM." in DETALLE3:
        return "LICENCIA DE AMPLIACIÓN-REMODELACIÓN Y DEMOLICIÓN PARCIAL"
    elif "CERCADO" in DETALLE3:
        return "LICENCIA DE CERCADO"
    elif "CERCO" in DETALLE3:
        return "LICENCIA DE CERCO"
    elif "AMPLIACION - REMODELACION" in DETALLE3:
        return "LICENCIA DE AMPLIACION - REMODELACION"
    elif "LICENCIA AMPLIACIÓN - REMODELACIÓN " in DETALLE3:
        return "LICENCIA DE AMPLIACION - REMODELACION"
    elif "REMODELACIÓN" in DETALLE3:
        return "LICENCIA DE REMODELACIÓN"
    elif "OBRA NUEVA" in DETALLE3:
        return "LICENCIA DE EDIFICACION OBRA NUEVA"
    elif "NUEVA" in DETALLE3:
        return "LICENCIA DE EDIFICACION OBRA NUEVA"
    elif "AMPLIACION - DEMOLICION PARCIAL" in DETALLE3:
        return "LICENCIA DE AMPLIACION - DEMOLICION PARCIAL"
    elif "AMPLIACION" in DETALLE3:
        return "LICENCIA DE AMPLIACIÓN"
    elif "APLIACION Y REMODELACION" in DETALLE3:
        return "LICENCIA DE AMPLIACION - REMODELACION"
    elif "DEMOLICION" in DETALLE3:
        return "LICENCIA DE DEMOLICION TOTAL"
    elif "False" in DETALLE3:
        return ""
    elif "LICENCIA DE AMPLIACIÓN" in DETALLE3:
        return "LICENCIA DE AMPLIACION"
    elif "EDIFICACION NEUEVA" in DETALLE3:
        return "LICENCIA DE EDIFICACION OBRA NUEVA"
    elif "REMODELACION" in DETALLE3:
        return "LICENCIA DE REMODELACION"
    elif "REMODELCION" in DETALLE3:
        return "LICENCIA DE REMODELACION"
    elif "MODIFICACION DE PROYECTO" in DETALLE3:
        return "LICENCIA DE MODIFICACION DE PROYECTO"
    else:
        return DETALLE3

df_ordenado2['TIPO OBRA NORMALIZADO'] = df_ordenado2['TIPO OBRA'].apply(OBRA2)

df_ordenado2['TIPO OBRA NORMALIZADO'].value_counts(dropna=False).sort_index()
# Out:
#                                          12
# LICENCIA DE AMPLIACION - REMODELACION     3
# LICENCIA DE AMPLIACIÓN                   26
# LICENCIA DE CERCO                         5
# LICENCIA DE DEMOLICION TOTAL             54
# LICENCIA DE EDIFICACION OBRA NUEVA       35
# LICENCIA DE MODIFICACION DE PROYECTO      1
# LICENCIA DE REMODELACION                  9
# nan                                       1
# Name: TIPO OBRA NORMALIZADO, dtype: int64

# %%
df_ordenado2['TIPO OBRA'] = df_ordenado2['TIPO OBRA NORMALIZADO']
df_ordenado2
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 93           301285         150136          PE         Lima      Lima
# 94           301285         150136          PE         Lima      Lima
# 95           301285         150136          PE         Lima      Lima
# 96           301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 50           301285         150136          PE         Lima      Lima
# 51           301285         150136          PE         Lima      Lima
# 52           301285         150136          PE         Lima      Lima
# 36           301285         150136          PE         Lima      Lima
# 145          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado2 = df_ordenado2.drop('TIPO OBRA NORMALIZADO', axis=1)

# %% [markdown]
# Numéricos

# %% [markdown]
# Generalización:

# %%
numeric_columns2 = ['OBRA NUEVA', 'OBRA DEMOLICIÓN',
               'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN',
               'OBRA CERCO','AREA TOTAL CONSTRUIDA', 'VALOR OBRA']

# %%
df_ordenado2[['OBRA NUEVA', 'OBRA DEMOLICIÓN',
               'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN',
               'OBRA CERCO','AREA TOTAL CONSTRUIDA', 'VALOR OBRA']]=df_ordenado2.iloc[:,[22,23,24,25,26,27,28,29]].replace(',','.',regex=True).replace(" ","",regex=True).replace("ML","",regex=True).replace("M2","",regex=True).replace("´","",regex=True).replace("’","",regex=True).replace("-","",regex=True).replace("--","",regex=True)
df_ordenado2[['OBRA NUEVA', 'OBRA DEMOLICIÓN',
               'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN',
               'OBRA CERCO','AREA TOTAL CONSTRUIDA', 'VALOR OBRA']]
# Out:
#     OBRA NUEVA OBRA DEMOLICIÓN OBRA REMODELACIÓN OBRA AMPLIACIÓN  \
# 0     9.256.95
# 93                         192
# 94                       345.1
# 95                       167.5
# 96                                            19           35.24
# ..         ...             ...               ...             ...
# 50                      222.64
# 51                       44.25
# 52                        85.5                             139.2
# 36                                         65.92
# 145                                           10
#
#     OBRA REFACCIÓN OBRA CERCO AREA TOTAL CONSTRUIDA    VALOR OBRA
# 0                                          9.256.95  9.040.482.29
# 93                                              192     18.880.00
# 94                                            345.1    140.974.73
# 95                                            167.5     62.675.30
# 96                                            35.24     23.939.72
# ...

# %%
df_ordenado2[['OBRA NUEVA', 'OBRA DEMOLICIÓN',
               'OBRA REMODELACIÓN', 'OBRA AMPLIACIÓN', 'OBRA REFACCIÓN',
               'OBRA CERCO','AREA TOTAL CONSTRUIDA', 'VALOR OBRA']]
# Out:
#     OBRA NUEVA OBRA DEMOLICIÓN OBRA REMODELACIÓN OBRA AMPLIACIÓN  \
# 0     9.256.95
# 93                         192
# 94                       345.1
# 95                       167.5
# 96                                            19           35.24
# ..         ...             ...               ...             ...
# 50                      222.64
# 51                       44.25
# 52                        85.5                             139.2
# 36                                         65.92
# 145                                           10
#
#     OBRA REFACCIÓN OBRA CERCO AREA TOTAL CONSTRUIDA    VALOR OBRA
# 0                                          9.256.95  9.040.482.29
# 93                                              192     18.880.00
# 94                                            345.1    140.974.73
# 95                                            167.5     62.675.30
# 96                                            35.24     23.939.72
# ...

# %%
badValues2 = []
for col in numeric_columns2:
    currentBad = df_ordenado2.loc[:, col].astype(str).str.contains('^\\d+\\.*\\d*$', na=False)
    badValues2.extend(df_ordenado2.loc[:, col][~currentBad])
badValues2 = list(set(badValues2))
print(badValues2)
# Out:
# ['', '1.360.94', '14.453.68', '57.081.99', '23.939.72', '3.850.00', '62.675.30', '136.581.41', '65.537.50', '155.386.12', '1.168.033.10', '1.579.57', '3.963.26', '149.221.12', '9.431.40', '1.089.354.33', '246.756.60', '1.518.268.50', '388.344.95', '10.014.531.38', '179.026.64', '52.880.00', '539.987.96', '553.892.00', '3.118.400.65', '3.578.853.53', '82.925.65', '24.224.56', -2.78, '5.087.83', '1.555.75', '459.923.10', '59.554.34', '57.178.00', '157.214.64', '11.012.60', '24.420.00', '2.000.304.20', '5.251.00', '7.808.193.30', '98.596.40', '122.093.95', '42.575.78', nan, '106.156.54', '191.729.28', '82.192.60', '727.518.95', '1.046.55', '9.514.34', '264.715.60', '102.847.27', '21.793.95', '69.784.21', '19.762.21', '341.705.65', '29.981.10', '1.365.99', '25.805.89', '140.000.00', '1.431.60', '140.664.54', '711.486.02', '4.505.25', '248.148.15', '2.605.70', '19.822.82', '124.874.78', '571.473.65', '56.863.66', '3.264.21', '190.171.96', '6.626.94', '189.295.32', '1.254.42', '140.974.73'
# ...

# %%
def corregir_numero(valor2):
    if isinstance(valor2, str):
        valor2 = valor2.strip()
        valor2 = valor2.replace(',', '.')
        partes = valor2.split('.')
        if len(partes) > 2:
            valor_corregido = ''.join(partes[:-1]) + '.' + partes[-1]
        else:
            valor_corregido = valor2
        return valor_corregido
    return valor2

df_ordenado2['VALOR OBRA'] = df_ordenado2['VALOR OBRA'].apply(corregir_numero)

df_ordenado2['VALOR OBRA'] = pd.to_numeric(df_ordenado2['VALOR OBRA'], errors='coerce')

print(df_ordenado2['VALOR OBRA'])
# Out:
# 0      9040482.29
# 93       18880.00
# 94      140974.73
# 95       62675.30
# 96       23939.72
#           ...
# 50       19350.53
# 51       19350.53
# 52      124874.78
# 36      114390.45
# 145       8388.00
# Name: VALOR OBRA, Length: 146, dtype: float64

# %%
badValues3 = []
for col in numeric_columns2:
    currentBad = df_ordenado2.loc[:, col].astype(str).str.contains('^\\d+\\.*\\d*$', na=False)
    badValues3.extend(df_ordenado2.loc[:, col][~currentBad])
badValues3 = list(set(badValues3))
print(badValues3)
# Out:
# ['', '5.136.85', nan, '1.360.94', '9.256.95', '1.046.55', '9.514.34', '1.579.57', '2.029.85', '3.963.26', '21.793.95', '230.010.31', '1.365.99', nan, '1.431.60', '2.605.70', '1.600.43', '1.026.46', '6.924.31', '3.264.21', '3.626.28', '24.224.56', '13.702.54', '1.254.42', '5.087.83', '10.029.65', '1.555.75', -35.95, '1.257.42', '11.012.60', '3.144.60', '4.134.76', '.', '83.229.45', -2.78]

# %%
df_ordenado2["OBRA NUEVA"] #PROBLEMAS
# Out:
# 0      9.256.95
# 93
# 94
# 95
# 96
#          ...
# 50
# 51
# 52
# 36
# 145
# Name: OBRA NUEVA, Length: 146, dtype: object

# %%
df_ordenado2['NRO DOC SOLICITANTE'] = df_ordenado2['NRO DOC SOLICITANTE'] .astype(str)
df_ordenado2['NRO DOC SOLICITANTE'].head()
# Out:
# 0     20555376361
# 93     2053871817
# 94    20607004367
# 95       15852335
# 96        8713889
# Name: NRO DOC SOLICITANTE, dtype: object

# %%
df_ordenado2[['VALOR OBRA']]
# Out:
#      VALOR OBRA
# 0    9040482.29
# 93     18880.00
# 94    140974.73
# 95     62675.30
# 96     23939.72
# ..          ...
# 50     19350.53
# 51     19350.53
# 52    124874.78
# 36    114390.45
# 145     8388.00
#
# [146 rows x 1 columns]

# %% [markdown]
# ## 9. Columnas Categóricas

# %%
df_ordenado2['VALOR OBRA CATEGORIA'] = pd.qcut(df_ordenado2['VALOR OBRA'], q=3, labels=['Bajo', 'Mediano', 'Alto'])
df_ordenado2['VALOR OBRA CATEGORIA']
# Out:
# 0         Alto
# 93        Bajo
# 94     Mediano
# 95        Bajo
# 96        Bajo
#         ...
# 50        Bajo
# 51        Bajo
# 52     Mediano
# 36     Mediano
# 145       Bajo
# Name: VALOR OBRA CATEGORIA, Length: 146, dtype: category
# Categories (3, object): ['Bajo' < 'Mediano' < 'Alto']

# %%
mapper1a = {'Bajo': 1 ,'Mediano': 3,'Alto':5}
mapper2a = {'E': 1 ,'D': 2,'C':3, "B":4, "A":5}

df_ordenado2['VALOR OBRA CATEGORIA'].replace(mapper1a,inplace=True)
df_ordenado2['MODALIDAD APROBACION'].replace(mapper2a,inplace=True)

# %%
df_ordenado2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           146 non-null    int64
#  1   CODIGO UBIGEO            146 non-null    int64
#  2   CODIGO PAIS              146 non-null    object
#  3   DEPARTAMENTO             146 non-null    object
#  4   PROVINCIA                146 non-null    object
#  5   DISTRITO                 146 non-null    object
#  6   NOMBRE UO                146 non-null    object
#  7   GOBIERNO LOCAL           146 non-null    object
#  8   RUC GOBIERNO LOCAL       146 non-null    int64
#  9   NUMERO EXPEDIENTE        146 non-null    object
#  10  FECHA INICIO TRAMITE     146 non-null    object
#  11  FECHA EMISION TRAMITE    146 non-null    int64
#  12  NRO RESOLUCION LICENCIA  146 non-null    object
#  13  TIPO DOC SOLICITANTE     146 non-null    object
# ...

# %%
newNames2=df_ordenado2.columns[20]+'_or'
newNames2
# Out:
# 'MODALIDAD APROBACION_or'

# %%
df_ordenado2[newNames2]=df_ordenado2.iloc[:,20]
df_ordenado2
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 93           301285         150136          PE         Lima      Lima
# 94           301285         150136          PE         Lima      Lima
# 95           301285         150136          PE         Lima      Lima
# 96           301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 50           301285         150136          PE         Lima      Lima
# 51           301285         150136          PE         Lima      Lima
# 52           301285         150136          PE         Lima      Lima
# 36           301285         150136          PE         Lima      Lima
# 145          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
from pandas.api.types import CategoricalDtype
myOrdinal2 = CategoricalDtype(categories=[1,2,3,4,5], ordered=True)

df_ordenado2.loc[:,"MODALIDAD APROBACION_or"].astype(myOrdinal2)
# Out:
# 0      3
# 93     5
# 94     5
# 95     5
# 96     4
#       ..
# 50     5
# 51     5
# 52     4
# 36     3
# 145    5
# Name: MODALIDAD APROBACION_or, Length: 146, dtype: category
# Categories (5, int64): [1 < 2 < 3 < 4 < 5]

# %%
df_ordenado2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           146 non-null    int64
#  1   CODIGO UBIGEO            146 non-null    int64
#  2   CODIGO PAIS              146 non-null    object
#  3   DEPARTAMENTO             146 non-null    object
#  4   PROVINCIA                146 non-null    object
#  5   DISTRITO                 146 non-null    object
#  6   NOMBRE UO                146 non-null    object
#  7   GOBIERNO LOCAL           146 non-null    object
#  8   RUC GOBIERNO LOCAL       146 non-null    int64
#  9   NUMERO EXPEDIENTE        146 non-null    object
#  10  FECHA INICIO TRAMITE     146 non-null    object
#  11  FECHA EMISION TRAMITE    146 non-null    int64
#  12  NRO RESOLUCION LICENCIA  146 non-null    object
#  13  TIPO DOC SOLICITANTE     146 non-null    object
# ...

# %%
df_ordenado2["MODALIDAD APROBACION_or"] = df_ordenado2["MODALIDAD APROBACION_or"].astype('category')

# %%
df_ordenado2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           146 non-null    int64
#  1   CODIGO UBIGEO            146 non-null    int64
#  2   CODIGO PAIS              146 non-null    object
#  3   DEPARTAMENTO             146 non-null    object
#  4   PROVINCIA                146 non-null    object
#  5   DISTRITO                 146 non-null    object
#  6   NOMBRE UO                146 non-null    object
#  7   GOBIERNO LOCAL           146 non-null    object
#  8   RUC GOBIERNO LOCAL       146 non-null    int64
#  9   NUMERO EXPEDIENTE        146 non-null    object
#  10  FECHA INICIO TRAMITE     146 non-null    object
#  11  FECHA EMISION TRAMITE    146 non-null    int64
#  12  NRO RESOLUCION LICENCIA  146 non-null    object
#  13  TIPO DOC SOLICITANTE     146 non-null    object
# ...

# %%
ordinalLevels2={1:'1_Bajo',2:'2_Mediano-Bajo',3:'3_Mediano',4:'4_Mediano-Alto',5:'5_Alto'}

renameLevels2= lambda x:x.cat.rename_categories(ordinalLevels2)

df_ordenado2.loc[:,"VALOR OBRA CATEGORIA":].apply(renameLevels2)
# Out:
#     VALOR OBRA CATEGORIA MODALIDAD APROBACION_or
# 0                 5_Alto               3_Mediano
# 93                1_Bajo                  5_Alto
# 94             3_Mediano                  5_Alto
# 95                1_Bajo                  5_Alto
# 96                1_Bajo          4_Mediano-Alto
# ..                   ...                     ...
# 50                1_Bajo                  5_Alto
# 51                1_Bajo                  5_Alto
# 52             3_Mediano          4_Mediano-Alto
# 36             3_Mediano               3_Mediano
# 145               1_Bajo                  5_Alto
#
# [146 rows x 2 columns]

# %%
df_ordenado2.loc[:,"VALOR OBRA CATEGORIA":]=df_ordenado2.loc[:,"VALOR OBRA CATEGORIA":].apply(renameLevels2)
df_ordenado2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           146 non-null    int64
#  1   CODIGO UBIGEO            146 non-null    int64
#  2   CODIGO PAIS              146 non-null    object
#  3   DEPARTAMENTO             146 non-null    object
#  4   PROVINCIA                146 non-null    object
#  5   DISTRITO                 146 non-null    object
#  6   NOMBRE UO                146 non-null    object
#  7   GOBIERNO LOCAL           146 non-null    object
#  8   RUC GOBIERNO LOCAL       146 non-null    int64
#  9   NUMERO EXPEDIENTE        146 non-null    object
#  10  FECHA INICIO TRAMITE     146 non-null    object
#  11  FECHA EMISION TRAMITE    146 non-null    int64
#  12  NRO RESOLUCION LICENCIA  146 non-null    object
#  13  TIPO DOC SOLICITANTE     146 non-null    object
# ...

# %%
df_ordenado2['OBRA NUEVA'] = pd.to_numeric(df_ordenado2['OBRA NUEVA'], errors='coerce')

# %%
df_ordenado2['OBRA DEMOLICIÓN'] = pd.to_numeric(df_ordenado2['OBRA DEMOLICIÓN'], errors='coerce')

# %%
df_ordenado2['OBRA AMPLIACIÓN'] = pd.to_numeric(df_ordenado2['OBRA AMPLIACIÓN'], errors='coerce')

# %%
df_ordenado2['OBRA REFACCIÓN'] = pd.to_numeric(df_ordenado2['OBRA REFACCIÓN'], errors='coerce')

# %%
df_ordenado2['OBRA CERCO'] = pd.to_numeric(df_ordenado2['OBRA CERCO'], errors='coerce')

# %%
df_ordenado2['AREA TOTAL CONSTRUIDA'] = pd.to_numeric(df_ordenado2['AREA TOTAL CONSTRUIDA'], errors='coerce')

# %% [markdown]
# ## 10. Fechas

# %%
def FECHAS2(CAMBIO2):
    CAMBIO_str2 = str(CAMBIO2)
    if '26/03/2021' in CAMBIO_str2:
        return "20210326"
    else:
        return CAMBIO_str2

df_ordenado2['FECHA INICIO TRAMITE'] = df_ordenado2['FECHA INICIO TRAMITE'].apply(FECHAS2)
df_ordenado2['FECHA INICIO TRAMITE'].value_counts(dropna=False).sort_index().head()
# Out:
# 20190820    1
# 20190827    1
# 20200222    1
# 20200311    1
# 20200916    1
# Name: FECHA INICIO TRAMITE, dtype: int64

# %%
df_ordenado2['FECHA INICIO TRAMITE'] = pd.to_datetime(df_ordenado2['FECHA INICIO TRAMITE'], format='%Y%m%d')
df_ordenado2['FECHA INICIO TRAMITE'].head()
# Out:
# 0    2020-12-30
# 93   2021-06-14
# 94   2021-07-23
# 95   2021-12-07
# 96   2021-07-23
# Name: FECHA INICIO TRAMITE, dtype: datetime64[ns]

# %%
df_ordenado2['FECHA EMISION TRAMITE'] = pd.to_datetime(df_ordenado2['FECHA EMISION TRAMITE'], format='%Y%m%d')
df_ordenado2['FECHA EMISION TRAMITE'].head()
# Out:
# 0    2021-01-04
# 93   2021-07-21
# 94   2021-08-06
# 95   2021-09-08
# 96   2021-08-23
# Name: FECHA EMISION TRAMITE, dtype: datetime64[ns]

# %%
df_ordenado2['FECHA CORTE'] = pd.to_datetime(df_ordenado2['FECHA CORTE'], format='%Y%m%d')
df_ordenado2['FECHA CORTE'].head()
# Out:
# 0    2021-12-31
# 93   2021-12-31
# 94   2021-12-31
# 95   2021-12-31
# 96   2021-12-31
# Name: FECHA CORTE, dtype: datetime64[ns]

# %%
df_ordenado2['AÑO'] = 2021
df_ordenado2
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 93           301285         150136          PE         Lima      Lima
# 94           301285         150136          PE         Lima      Lima
# 95           301285         150136          PE         Lima      Lima
# 96           301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 50           301285         150136          PE         Lima      Lima
# 51           301285         150136          PE         Lima      Lima
# 52           301285         150136          PE         Lima      Lima
# 36           301285         150136          PE         Lima      Lima
# 145          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %% [markdown]
# ## 11. Guardado del output

# %%
df_ordenado2
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 93           301285         150136          PE         Lima      Lima
# 94           301285         150136          PE         Lima      Lima
# 95           301285         150136          PE         Lima      Lima
# 96           301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 50           301285         150136          PE         Lima      Lima
# 51           301285         150136          PE         Lima      Lima
# 52           301285         150136          PE         Lima      Lima
# 36           301285         150136          PE         Lima      Lima
# 145          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_ordenado2.to_csv(os.path.join("data","df_ordenado2_Py.csv"),index=False )
df_ordenado2.to_pickle(os.path.join("data","df_ordenado2.pkl") )

# %%
dfPickle2=pd.read_pickle(os.path.join("data","df_ordenado2.pkl") )
dfCSV2=pd.read_csv(os.path.join("data","df_ordenado2_Py.csv") )

# %%
dfPickle2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146 entries, 0 to 145
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           146 non-null    int64
#  1   CODIGO UBIGEO            146 non-null    int64
#  2   CODIGO PAIS              146 non-null    object
#  3   DEPARTAMENTO             146 non-null    object
#  4   PROVINCIA                146 non-null    object
#  5   DISTRITO                 146 non-null    object
#  6   NOMBRE UO                146 non-null    object
#  7   GOBIERNO LOCAL           146 non-null    object
#  8   RUC GOBIERNO LOCAL       146 non-null    int64
#  9   NUMERO EXPEDIENTE        146 non-null    object
#  10  FECHA INICIO TRAMITE     146 non-null    datetime64[ns]
#  11  FECHA EMISION TRAMITE    146 non-null    datetime64[ns]
#  12  NRO RESOLUCION LICENCIA  146 non-null    object
# ...

# %%
dfCSV2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           146 non-null    int64
#  1   CODIGO UBIGEO            146 non-null    int64
#  2   CODIGO PAIS              146 non-null    object
#  3   DEPARTAMENTO             146 non-null    object
#  4   PROVINCIA                146 non-null    object
#  5   DISTRITO                 146 non-null    object
#  6   NOMBRE UO                146 non-null    object
#  7   GOBIERNO LOCAL           146 non-null    object
#  8   RUC GOBIERNO LOCAL       146 non-null    int64
#  9   NUMERO EXPEDIENTE        146 non-null    object
#  10  FECHA INICIO TRAMITE     146 non-null    object
#  11  FECHA EMISION TRAMITE    146 non-null    object
#  12  NRO RESOLUCION LICENCIA  146 non-null    object
#  13  TIPO DOC SOLICITANTE     146 non-null    object
# ...

# %%
df_ordenado_combinado = pd.concat([df_ordenado, df_ordenado], ignore_index=True)
df_ordenado_combinado
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 1            301285         150136          PE         Lima      Lima
# 2            301285         150136          PE         Lima      Lima
# 3            301285         150136          PE         Lima      Lima
# 4            301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 229          301285         150136          PE         Lima      Lima
# 230          301285         150136          PE         Lima      Lima
# 231          301285         150136          PE         Lima      Lima
# 232          301285         150136          PE         Lima      Lima
# 233          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %% [markdown]
# ## 12. Concatenación

# %%
df_unido = pd.concat([df_ordenado, df_ordenado2], ignore_index=True)

print(df_unido)
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 1            301285         150136          PE         Lima      Lima
# 2            301285         150136          PE         Lima      Lima
# 3            301285         150136          PE         Lima      Lima
# 4            301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 258          301285         150136          PE         Lima      Lima
# 259          301285         150136          PE         Lima      Lima
# 260          301285         150136          PE         Lima      Lima
# 261          301285         150136          PE         Lima      Lima
# 262          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_unido
# Out:
#      CODIGO ENTIDAD  CODIGO UBIGEO CODIGO PAIS DEPARTAMENTO PROVINCIA  \
# 0            301285         150136          PE         Lima      Lima
# 1            301285         150136          PE         Lima      Lima
# 2            301285         150136          PE         Lima      Lima
# 3            301285         150136          PE         Lima      Lima
# 4            301285         150136          PE         Lima      Lima
# ..              ...            ...         ...          ...       ...
# 258          301285         150136          PE         Lima      Lima
# 259          301285         150136          PE         Lima      Lima
# 260          301285         150136          PE         Lima      Lima
# 261          301285         150136          PE         Lima      Lima
# 262          301285         150136          PE         Lima      Lima
#
#        DISTRITO                      NOMBRE UO GOBIERNO LOCAL  \
# 0    San Miguel  Subgerencia de Obras Privadas     San Miguel
# ...

# %%
df_unido.to_csv(os.path.join("data","df_unido_Py.csv"),index=False )
df_unido.to_pickle(os.path.join("data","df_unido.pkl") )

# %%
dfPickle_unido=pd.read_pickle(os.path.join("data","df_unido.pkl") )
dfCSV_unido=pd.read_csv(os.path.join("data","df_unido_Py.csv") )

# %%
dfPickle_unido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           263 non-null    int64
#  1   CODIGO UBIGEO            263 non-null    int64
#  2   CODIGO PAIS              263 non-null    object
#  3   DEPARTAMENTO             263 non-null    object
#  4   PROVINCIA                263 non-null    object
#  5   DISTRITO                 263 non-null    object
#  6   NOMBRE UO                263 non-null    object
#  7   GOBIERNO LOCAL           263 non-null    object
#  8   RUC GOBIERNO LOCAL       263 non-null    int64
#  9   NUMERO EXPEDIENTE        263 non-null    object
#  10  FECHA INICIO TRAMITE     225 non-null    datetime64[ns]
#  11  FECHA EMISION TRAMITE    261 non-null    datetime64[ns]
#  12  NRO RESOLUCION LICENCIA  263 non-null    object
# ...

# %%
dfCSV_unido.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 263 entries, 0 to 262
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CODIGO ENTIDAD           263 non-null    int64
#  1   CODIGO UBIGEO            263 non-null    int64
#  2   CODIGO PAIS              263 non-null    object
#  3   DEPARTAMENTO             263 non-null    object
#  4   PROVINCIA                263 non-null    object
#  5   DISTRITO                 263 non-null    object
#  6   NOMBRE UO                263 non-null    object
#  7   GOBIERNO LOCAL           263 non-null    object
#  8   RUC GOBIERNO LOCAL       263 non-null    int64
#  9   NUMERO EXPEDIENTE        263 non-null    object
#  10  FECHA INICIO TRAMITE     225 non-null    object
#  11  FECHA EMISION TRAMITE    261 non-null    object
#  12  NRO RESOLUCION LICENCIA  263 non-null    object
#  13  TIPO DOC SOLICITANTE     263 non-null    object
# ...
